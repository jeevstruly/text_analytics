# %%
import requests
import json
import os
import dotenv
import pandas as pd

# %%
print("Current Working Directory:",(os.getcwd()))
# Out:
# Current Working Directory: c:\Users\RJR-AS\Documents\TextAnalyticsVS\text_analytics

# %%
contentText3="""Thor Steel is introducing a new vibranium bread in the market. Thor Steel is new to the bread market. The bread launch will take place in stages, leading up to summer 2025. Thor Steel CEO, Bruce Banner, will be speaking more about the launch at Thor Steel shareholder lunch and launch. There are around 63 firm orders for the upcoming Airbus A350F based on the Airbus A350-900 passenger aircraft. The aircraft had been expected to enter service in 2026, but that has now been pushed back to 2027. Still, expectations are high for the Airbus A350F . Currently, the world is looking forward to the introduction of two new freighters, the Boeing 777X freighter and the Airbus A350F.
The A350 has proven a popular platform and one that is well adapted to being used as a freighter. This is in contrast with the Airbus A380, which is poorly designed to function as a freighter. Here is what to know about the orders for the Airbus A350F.

Airbus A350F orders
Ch-aviation lists that over nine customers have so far ordered 66 Airbus A350F cargo aircraft."""


contentText2 = """GSK and Vir Biotechnology announce United States government agreement to purchase additional supply of sotrovimab, authorised for the early treatment of COVID-19
For media and investors only Issued: London, UK and San Francisco, US
600,000 additional doses to be supplied to the US Government for distribution in Q1 2022, enabling further access to sotrovimab nationwide
Brings total number of doses secured to date through binding agreements to approximately 1.7 million globally
Preclinical data generated through both pseudo-virus and live virus testing demonstrate sotrovimab retains activity against all tested SARS-CoV-2 variants of concern including Delta and Omicron
GlaxoSmithKline plc (LSE/NYSE: GSK) and Vir Biotechnology, Inc. (Nasdaq: VIR) today announced that the US Government will purchase an additional 600,000 doses of sotrovimab, an investigational monoclonal antibody for the early treatment of COVID-19, enabling further nationwide access to sotrovimab for patients. The additional 600,000 doses will be delivered throughout the first quarter of 2022. This agreement is an amendment to earlier commitments announced with the US Government in November 2021.
Including the commitments announced today, GSK and Vir have received binding agreements for the sale of approximately 1.7 million doses of sotrovimab worldwide. In addition, today’s agreement also includes the option for the US government to purchase further additional doses in the second quarter of 2022.
Sotrovimab, which was granted Emergency Use Authorization (EUA) by the US Food and Drug Administration (FDA) in May 2021, is an investigational single-dose intravenous (IV) infusion SARS-CoV-2 monoclonal antibody. Under the EUA, sotrovimab can be used for the treatment of mild-to-moderate COVID-19 in adults and paediatric patients (12 years of age and older weighing at least 40 kg) with positive results of direct SARS-CoV-2 viral testing, and who are at high risk for progression to severe COVID-19, including hospitalisation or death.
GSK and Vir expect to manufacture approximately 2 million doses globally in the first half of 2022 and additional doses in the second half of the year.
Maya Martinez-Davis, President, US Pharmaceuticals, GSK, said: “We are proud to continue to work with the US government to bring sotrovimab to patients who need it, especially as the Omicron variant continues to grow in prevalence across the country. We understand the role we can play in supporting the ongoing pandemic response, and our teams are working with urgency to explore options to expand our supply capacity so we can support more patients in 2022.”
George Scangos, PhD, chief executive officer of Vir, said: “As the Omicron variant continues its rapid spread alongside the still prevalent Delta variant, we are pleased to once again work with the US government to provide more access to sotrovimab for people in the US at high risk of progression to severe COVID-19. Data from multiple pseudo-virus and live virus preclinical studies, generated by industry and academia, continue to demonstrate that sotrovimab retains activity against all tested variants of concern and interest. We are proud of our ongoing contributions to the fight against the COVID-19 pandemic here in the US and around the world.”
The Biomedical Advanced Research and Development Authority (BARDA), part of the Department of Health and Human Services (HHS) Office of the Assistant Secretary for Preparedness and Response (ASPR), collaborated with the Department of Defense Joint Program Executive Office for Chemical, Biological, Radiological and Nuclear Defense (JPEO-CBRND) and Army Contracting Command to purchase contract numbers W58P0521C0008 and W58P0522C0002.
In June 2021, GSK and Vir announced confirmatory full results for the COMET-ICE Phase III trial examining use of sotrovimab for early treatment of mild-to-moderate COVID-19 in high-risk, non-hospitalised adults. The trial met the primary endpoint with a 79% reduction (adjusted relative risk reduction) (p<0.001) in all-cause hospitalisations for more than 24 hours or death due to any cause by Day 29 compared to placebo. In absolute numbers, 30 (6%) of the 529 patients in the placebo arm progressed, compared to six (1%) of the 528 patients receiving sotrovimab. In clinical trials conducted to date, sotrovimab has been well-tolerated. The most common adverse reactions are hypersensitivity and infusion-related reactions, seen in approximately 2% and 1% of cases, respectively.
GSK and Vir are committed to the ongoing evaluation of sotrovimab as the COVID-19 landscape continues to evolve at different rates across the globe and new variants of concern and interest emerge. Preclinical pseudo-virus data, published in bioRxiv, demonstrate that sotrovimab retains activity against all tested variants of concern and interest of the SARS-CoV-2 virus as defined by the World Health Organization, including, but not limited to, Omicron (B.1.1.529), Delta (B.1.617.2), Delta Plus (AY.1 or AY.2) and Mu (B.1.621). Preclinical live virus testing has also been completed with data, recently published in bioRxiv, further demonstrating that sotrovimab retains activity against the Omicron variant.
About sotrovimab
Sotrovimab is an investigational SARS-CoV-2 neutralising monoclonal antibody. The antibody binds to an epitope on SARS-CoV-2 shared with SARS-CoV-1 (the virus that causes SARS), indicating that the epitope is highly conserved, which may make it more difficult for resistance to develop. Sotrovimab, which incorporates Xencor, Inc.’s Xtend™ technology, has also been designed to achieve high concentration in the lungs to ensure optimal penetration into airway tissues affected by SARS-CoV-2 and to have an extended half-life."""

contentText1= """ Abbott Labs Lifts FY24 Outlook After 2Q Sales Rise
Published: July 18, 2024 at 8:06 a.m. ET
By Dean Seal
Abbott Laboratories raised its full-year earnings guidance after reporting sales gains in the second quarter from its nutrition and medical devices segments.
The Abbott Park, Ill.-based healthcare products company said it now expects earnings of $3.30 to $3.40 a share, adding 5 cents to the lower end of its previous guidance.
When adjusted for one-time items, the company expects earnings of $4.61 to $4.71 a share, up from a prior range of $4.55 to $4.70 a share.
The company also increased the lower end of its outlook for organic sales growth, excluding Covid-19 testing, to 9.5% from 8.5%.

For the second quarter, the Pedialyte maker posted a profit of $1.3 billion, or 74 cents a share, compared with $1.38 billion, or 78 cents a share, in the same quarter a year ago.
Adjusted earnings were $1.14 a share, clearing analyst projections by 3 cents, according to FactSet.

Sales rose 4% to $10.38 billion, in line with analyst forecasts. The top line grew 7.4% on an organic basis, which excludes foreign currency translations, the discontinuing of its ZonePerfect product line and its acquisition of Cardiovascular Systems.
The company's adult nutrition segment performed well thanks to growth of its Ensure nutrition brand, while its diagnostics unit was dented by declines in Covid-19 testing-related sales.

Sales in its medical devices business were up more than 10%, led by its Diabetes Care, Electrophysiology, and Structural Heart products.
Write to Dean Seal at dean.seal@wsj.com """


contentText= """There are around 63 firm orders for the upcoming Airbus A350F based on the Airbus A350-900 passenger aircraft. The aircraft had been expected to enter service in 2026, but that has now been pushed back to 2027. Still, expectations are high for the Airbus A350F . Currently, the world is looking forward to the introduction of two new freighters, the Boeing 777X freighter and the Airbus A350F.
The A350 has proven a popular platform and one that is well adapted to being used as a freighter. This is in contrast with the Airbus A380, which is poorly designed to function as a freighter. Here is what to know about the orders for the Airbus A350F.

Airbus A350F orders
Ch-aviation lists that over nine customers have so far ordered 66 Airbus A350F cargo aircraft. Perhaps surprisingly, some of the big air freighter companies like DHL and FedEx do not appear to have placed firm orders for the aircraft."""

# %%
#Step 3 get intelligent tagging response from Hosted RIT

from dotenv import load_dotenv
import os

load_dotenv()
it_api_key = os.getenv('API_KEY9')

## Check if the API key is loaded correctly
## otherwise manually add

print(it_api_key)

url= "https://api-eit.refinitiv.com/permid/calais" #endpoint
payload = contentText2.encode('utf8')
headers = {
    'Content-Type': "text/raw",
    'X-AG-Access-Token': it_api_key, # token called here
    'outputformat': "application/json",
    'x-calais-contentClass': "news",
    #'x-calais-selectiveTags': "topic-all, socialtags, industry, Organization, Person, Journalist, Company, Editor "
    }

TRITResponse = requests.post(url, data=payload, headers = headers)
# Out:
# A8gYlKK8krmJ5LIAsAG6CglvchV9cPe4

# %%
print(TRITResponse.headers)
# Out:
# {'Date': 'Fri, 08 Aug 2025 17:13:32 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-RateLimit-Remaining-second': '1', 'X-RateLimit-Limit-second': '2', 'RateLimit-Limit': '5000', 'RateLimit-Reset': '24389', 'RateLimit-Remaining': '4994', 'X-RateLimit-Limit-day': '5000', 'X-RateLimit-Remaining-day': '4994', 'X-RateLimit-Limit-RequestSize': '500000000', 'X-RateLimit-Remaining-RequestSize': '499994220', 'Set-Cookie': 'TR-TMS-MDaaS-SESSIONID=AZiKrGh2DKvIeDseAHHF^cac8fd85;Path=/;HttpOnly', 'Expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'DurationMillis': '1426', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding, Origin', 'Access-Control-Allow-Credentials': 'true', 'Strict-Transport-Security': 'max-age=31536000'}

# %%
print(TRITResponse.text)
# Out:
# {"doc":{"info":{"id":"http:\/\/id.opencalais.com\/27GBBLJtaB1pd9vjVfhq1A","ontology":"http:\/\/trit-us-east-1-sharedamd.int.refinitiv.com\/owlschema\/0.5.2\/onecalais.owl.allmetadata.xml","docId":"http:\/\/d.opencalais.com\/dochash-1\/e959465d-fb0b-3829-ac89-a6d435131421","document":"GSK and Vir Biotechnology announce United States government agreement to purchase additional supply of sotrovimab, authorised for the early treatment of COVID-19\nFor media and investors only Issued: London, UK and San Francisco, US\n600,000 additional doses to be supplied to the US Government for distribution in Q1 2022, enabling further access to sotrovimab nationwide\nBrings total number of doses secured to date through binding agreements to approximately 1.7 million globally\nPreclinical data generated through both pseudo-virus and live virus testing demonstrate sotrovimab retains activity against all tested SARS-CoV-2 variants of concern including Delta and Omicron\nGlaxoSmithKline plc (LSE\/NYSE: GSK) and Vir Biotechnology, Inc. (Nasdaq: VIR) today announced that the US Government will purchase an additional 600,000 doses of sotrovimab, an investigational monoclonal antibody for the early treatment of COVID-19, enabling further nationwide access to sotrovimab for patients. The additional 600,000 doses will be delivered throughout the first quarter of 2022. This agreement is an amendment to earlier commitments announced with the US Government in November 2021.\nIncluding the commitments announced today, GSK and Vir have received binding agreements for the sale of approximately 1.7 million doses of sotrovimab worldwide. In addition, today’s agreement also includes the option for the US government to purchase further additional doses in the second quarter of 2022.\nSotrovimab, which was granted Emergency Use Authorization (EUA) by the US Food and Drug Administration (FDA) in May 2021, is an investigational single-dose intravenous (IV) infusion SARS-CoV-2 monoclonal antibody. Under the EUA, sotrovimab can be used for the treatment of mild-to-moderate COVID-19 in adults and paediatric patients (12 years of age and older weighing at least 40 kg) with positive results of direct SARS-CoV-2 viral testing, and who are at high risk for progression to severe COVID-19, including hospitalisation or death.\nGSK and Vir expect to manufacture approximately 2 million doses globally in the first half of 2022 and additional doses in the second half of the year.\nMaya Martinez-Davis, President, US Pharmaceuticals, GSK, said: “We are proud to continue to work with the US government to bring sotrovimab to patients who need it, especially as the Omicron variant continues to grow in prevalence across the country. We understand the role we can play in supporting the ongoing pandemic response, and our teams are working with urgency to explore options to expand our supply capacity so we can support more patients in 2022.”\nGeorge Scangos, PhD, chief executive officer of Vir, said: “As the Omicron variant continues its rapid spread alongside the still prevalent Delta variant, we are pleased to once again work with the US government to provide more access to sotrovimab for people in the US at high risk of progression to severe COVID-19. Data from multiple pseudo-virus and live virus preclinical studies, generated by industry and academia, continue to demonstrate that sotrovimab retains activity against all tested variants of concern and interest. We are proud of our ongoing contributions to the fight against the COVID-19 pandemic here in the US and around the world.”\nThe Biomedical Advanced Research and Development Authority (BARDA), part of the Department of Health and Human Services (HHS) Office of the Assistant Secretary for Preparedness and Response (ASPR), collaborated with the Department of Defense Joint Program Executive Office for Chemical, Biological, Radiological and Nuclear Defense (JPEO-CBRND) and Army Contracting Command to purchase contract numbers W58P052 ...

# %%
JSONResponse = json.loads(TRITResponse.text)

# %%
print(json.dumps(JSONResponse, indent = 4))
# Out:
# {
#     "doc": {
#         "info": {
#             "id": "http://id.opencalais.com/27GBBLJtaB1pd9vjVfhq1A",
#             "ontology": "http://trit-us-east-1-sharedamd.int.refinitiv.com/owlschema/0.5.2/onecalais.owl.allmetadata.xml",
#             "docId": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421",
#             "document": "GSK and Vir Biotechnology announce United States government agreement to purchase additional supply of sotrovimab, authorised for the early treatment of COVID-19\nFor media and investors only Issued: London, UK and San Francisco, US\n600,000 additional doses to be supplied to the US Government for distribution in Q1 2022, enabling further access to sotrovimab nationwide\nBrings total number of doses secured to date through binding agreements to approximately 1.7 million globally\nPreclinical data generated through both pseudo-virus and live virus testing demonstrate sotrovimab retains activity against all tested SARS-CoV-2 variants of concern including Delta and Omicron\nGlaxoSmithKline plc (LSE/NYSE: GSK) and Vir Biotechnology, Inc. (Nasdaq: VIR) today announced that the US Government will purchase an additional 600,000 doses of sotrovimab, an investigational monoclonal antibody for the early treatment of COVID-19, enabling further nationwide access to sotrovimab for patients. The additional 600,000 doses will be delivered throughout the first quarter of 2022. This agreement is an amendment to earlier commitments announced with the US Government in November 2021.\nIncluding the commitments announced today, GSK and Vir have received binding agreements for the sale of approximately 1.7 million doses of sotrovimab worldwide. In addition, today\u2019s agreement also includes the option for the US government to purchase further additional doses in the second quarter of 2022.\nSotrovimab, which was granted Emergency Use Authorization (EUA) by the US Food and Drug Administration (FDA) in May 2021, is an investigational single-dose intravenous (IV) infusion SARS-CoV-2 monoclonal antibody. Under the EUA, sotrovimab can be used for the treatment of mild-to-moderate COVID-19 in adults and paediatric patients (12 years of age and older weighing at least 40 kg) with positive results of direct SARS-CoV-2 viral testing, and who are at high risk for progression to severe COVID-19, including hospitalisation or death.\nGSK and Vir expect to manufacture approximately 2 million doses globally in the first half of 2022 and additional doses in the second half of the year.\nMaya Martinez-Davis, President, US Pharmaceuticals, GSK, said: \u201cWe are proud to continue to work with the US government to bring sotrovimab to patients who need it, especially as the Omicron variant continues to grow in prevalence across the country. We understand the role we can play in supporting the ongoing pandemic response, and our teams are working with urgency to explore options to expand our supply capacity so we can support more patients in 2022.\u201d\nGeorge Scangos, PhD, chief executive officer of Vir, said: \u201cAs the Omicron variant continues its rapid spread alongside the still prevalent Delta variant, we are pleased to once again work with the US government to provide more access to sotrovimab for people in the US at high risk of progression to severe COVID-19. Data from multiple pseudo-virus and live virus preclinical studies, generated by industry and academia, continue to demonstrate that sotrovimab retains activity against all tested variants of concern and interest. We are proud of our ongoing contributions to the fight against the COVID-19 pandemic here in the US and around the world.\u201d\nThe Biomedical Advanced Research and Development Authority (BARDA), part of the Department of Health and Human Services (HHS) Office of the Assistant Secretary for Preparedness and Response (ASPR), collaborated with the Department of Defense Joint Program Executive Office for Chemical, Biological, Radiological and Nuclear Defense (JPEO-CBRND) and Army Contracting Command to purchase contract numbers W58P0521C0008 and W58P0522C0002.\nIn June 2021, GSK and Vir announced confirmatory full results for the COMET-ICE Phase III trial examining use of sotrovimab for early treatment of mild-to-moderate COVID-19 in high-risk, non-hospitalised adult ...
#             "docTitle": "For media and investors only Issued: London, UK and San Francisco, US",
#             "docDate": "2025-08-08 17:13:32.367"
#         },
#         "meta": {
#             "contentClass": "news",
#             "contentType": "text/raw",
#             "processingVer": "AllMetadata",
#             "serverVersion": "N/A",
#             "stagsVer": "defaultVersion",
#             "submissionDate": "2025-08-08 17:13:31.572",
#             "submitterCode": "2362b867-7324-6cab-fb2e-2a48761bfb77",
#             "signature": "digestalg-1|HIqJpQ/+JzdjjRfOBn05k2KYO+4=|D3RaixRpi8/d4/qYHGruBxbHL6ImVq1HgAPNXvgU3bSTGRlgWzzfUQ==",
#             "language": "English"
#         }
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/cat/1": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "false",
#         "score": 1,
#         "name": "Health_Medical_Pharma"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/cat/2": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "false",
#         "score": 0.85,
#         "name": "Business_Finance"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/cat/3": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "false",
#         "rcscode": "M:P",
#         "name": "Health / Medicine",
#         "permid": "400672",
#         "score": 1
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/cat/4": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "false",
#         "rcscode": "M:V",
#         "name": "Science",
#         "permid": "201099",
#         "score": 0.761
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/cat/5": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "false",
#         "rcscode": "B:156",
#         "name": "Pharmaceuticals & Medical Research (TRBC)",
#         "permid": "4294952845",
#         "score": 0.724
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/cat/6": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "true",
#         "rcscode": "M:1ZN",
#         "name": "Press Releases",
#         "permid": "1004026377",
#         "score": 0.948
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/cat/7": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "true",
#         "rcscode": "M:1LP",
#         "name": "Public Health",
#         "permid": "386041",
#         "score": 0.375
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/cat/8": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "true",
#         "rcscode": "M:1L7",
#         "name": "Drug & Device Development",
#         "permid": "386025",
#         "score": 0.527
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/cat/9": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "true",
#         "rcscode": "M:3C1",
#         "name": "M_3C1",
#         "score": 0.963
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/lid/DefaultLangId": {
#         "_typeGroup": "language",
#         "language": "http://d.opencalais.com/lid/DefaultLangId/English",
#         "forenduserdisplay": "false",
#         "permid": "505062"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/1": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/1",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/3d389671-8f39-3cd4-acaa-c044a605b956",
#         "forenduserdisplay": "true",
#         "name": "COVID-19 drug development",
#         "importance": "1",
#         "originalValue": "COVID-19 drug development"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/2": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/2",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/be2964ab-d390-3851-9d38-ffc49538245e",
#         "forenduserdisplay": "true",
#         "name": "Monoclonal antibodies",
#         "importance": "1",
#         "originalValue": "Monoclonal antibodies"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/3": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/3",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/76ff7e8c-4a4f-3870-8124-995b4d46e493",
#         "forenduserdisplay": "true",
#         "name": "Occupational safety and health",
#         "importance": "1",
#         "originalValue": "Occupational safety and health"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/4": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/4",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/c44943cf-67ac-381d-b564-24e12db6be15",
#         "forenduserdisplay": "true",
#         "name": "Sotrovimab",
#         "importance": "2",
#         "originalValue": "Sotrovimab"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/5": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/5",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/e5adb393-8493-31a8-827f-3f8064d4e2ad",
#         "forenduserdisplay": "true",
#         "name": "SARS-CoV-2 Omicron variant",
#         "importance": "2",
#         "originalValue": "SARS-CoV-2 Omicron variant"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/6": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/6",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/df8c55eb-e856-3fa1-9eaf-5792b29a9755",
#         "forenduserdisplay": "true",
#         "name": "SARS-CoV-2 Delta variant",
#         "importance": "2",
#         "originalValue": "SARS-CoV-2 Delta variant"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/7": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/7",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/bcad9984-0424-39aa-892c-9c70b9f48f45",
#         "forenduserdisplay": "true",
#         "name": "COVID-19 pandemic",
#         "importance": "2",
#         "originalValue": "COVID-19 pandemic"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/8": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/8",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/e1a251e4-462b-3faf-95a4-88acf378871b",
#         "forenduserdisplay": "true",
#         "name": "Variants of SARS-CoV-2",
#         "importance": "2",
#         "originalValue": "Variants of SARS-CoV-2"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/9": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/9",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/79f772c6-959f-364b-9d89-23cabbb885a3",
#         "forenduserdisplay": "true",
#         "name": "SARS-CoV-2 Mu variant",
#         "importance": "2",
#         "originalValue": "SARS-CoV-2 Mu variant"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/10": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/10",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/40746ecc-a552-32d8-af84-87df1a7d64e0",
#         "forenduserdisplay": "true",
#         "name": "COVID-19",
#         "importance": "2",
#         "originalValue": "COVID-19"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/11": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/11",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/73d4340d-ff10-3ed8-888b-f612c54bcdf1",
#         "forenduserdisplay": "true",
#         "name": "SARS-CoV-2",
#         "importance": "2",
#         "originalValue": "SARS-CoV-2"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/12": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/SocialTag/12",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/1aa5c5ad-19ca-338f-b31f-b172b5a5d3a3",
#         "forenduserdisplay": "true",
#         "name": "Coronavirus spike protein",
#         "importance": "2",
#         "originalValue": "Coronavirus spike protein"
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/Industry/1": {
#         "_typeGroup": "industry",
#         "forenduserdisplay": "false",
#         "name": "Government & Government Finance (NEC)",
#         "rcscode": "B:1888",
#         "trbccode": "6210101010",
#         "permid": "1004365552",
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/Industry/2": {
#         "_typeGroup": "industry",
#         "forenduserdisplay": "false",
#         "name": "Government Administration Activities",
#         "rcscode": "B:1893",
#         "trbccode": "6210103010",
#         "permid": "1004365576",
#         "relevance": 0.5
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/Industry/3": {
#         "_typeGroup": "industry",
#         "forenduserdisplay": "false",
#         "name": "Biotechnology & Medical Research (NEC)",
#         "rcscode": "B:1736",
#         "trbccode": "5620201010",
#         "permid": "4294951265",
#         "relevance": 0.8
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/Industry/4": {
#         "_typeGroup": "industry",
#         "forenduserdisplay": "false",
#         "name": "Bio Therapeutic Drugs",
#         "rcscode": "B:1737",
#         "trbccode": "5620201011",
#         "permid": "4294951264",
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/Industry/5": {
#         "_typeGroup": "industry",
#         "forenduserdisplay": "false",
#         "name": "Pharmaceuticals (NEC)",
#         "rcscode": "B:1729",
#         "trbccode": "5620104010",
#         "permid": "4294951272",
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/dochash-1/e959465d-fb0b-3829-ac89-a6d435131421/ComponentVersions": {
#         "_typeGroup": "versions",
#         "version": [
#             "Deals Index:202507270800:202507270800",
#             "config-blackList-DIY:303065817:303065817",
#             "index-refineries:202403040723:202403040723",
#             "config-physicalAssets-powerStations:1227:1227",
#             "NextTags:2.5.193-legacy-trit-release-master:193",
#             "config-sca-DataPackage:50:50",
#             "config-companyNe:90613:90613",
#             "People Index:202508081620:202508081620",
#             "config-negativeSignature:994:994",
#             "Dial4J:2.0.17:17",
#             "OA Override:994:994",
#             "People Override:994:994",
#             "index-sluglines:202010230725:202010230725",
#             "index-vessels:202403050724:202403050724",
#             "config-forEndUserDisplay:4:4",
#             "config-refineries:994:994",
#             "config-cse-DIY:303061980:303061980",
#             "config-cse:994:994",
#             "config-vessels:994:994",
#             "override-company-DIY:303061980:303061980",
#             "config-physicalAssets-mines:1227:1227",
#             "BlackList:994:994",
#             "index-ports:202107101516:202107101516",
#             "config-physicalAssets-ports:994:994",
#             "config-drugs:994:994"
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/c63319ec-4e5a-3ba4-a14e-09f00a45e9c0": {
#         "_typeGroup": "entities",
#         "_type": "Organization",
#         "forenduserdisplay": "false",
#         "name": "World Health Organization",
#         "organizationtype": "governmental civilian",
#         "nationality": "N/A",
#         "resolutions": [
#             {
#                 "rcscode": "M:9B",
#                 "name": "World Health Organization"
#             }
#         ],
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Organization",
#         "permid": "https://permid.org/1-404010",
#         "instances": [
#             {
#                 "detection": "[of the SARS-CoV-2 virus as defined by the ]World Health Organization[, including, but not limited to, Omicron]",
#                 "prefix": "of the SARS-CoV-2 virus as defined by the ",
#                 "exact": "World Health Organization",
#                 "suffix": ", including, but not limited to, Omicron",
#                 "offset": 4901,
#                 "length": 25
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/a1c1ac3d-0c25-3fb1-ac74-cac9c8510afa": {
#         "_typeGroup": "entities",
#         "_type": "City",
#         "forenduserdisplay": "true",
#         "name": "San Francisco",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/City",
#         "instances": [
#             {
#                 "detection": "[media and investors only Issued: London, UK and ]San Francisco[, US\n600,000 additional doses to be supplied to]",
#                 "prefix": "media and investors only Issued: London, UK and ",
#                 "exact": "San Francisco",
#                 "suffix": ", US\n600,000 additional doses to be supplied to",
#                 "offset": 214,
#                 "length": 13
#             }
#         ],
#         "relevance": 0.2,
#         "resolutions": [
#             {
#                 "name": "San Francisco,California,United States",
#                 "shortname": "San Francisco",
#                 "latitude": "37.775",
#                 "longitude": "-122.4183",
#                 "containedbystate": "California",
#                 "containedbycountry": "United States",
#                 "rcscode": "G:27F"
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/8b6c7618-dc22-3047-bf8e-0a0630262b1a": {
#         "_typeGroup": "entities",
#         "_type": "MedicalCondition",
#         "forenduserdisplay": "false",
#         "name": "SARS",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/MedicalCondition",
#         "instances": [
#             {
#                 "detection": "[shared with SARS-CoV-1 (the virus that causes ]SARS[), indicating that the epitope is highly]",
#                 "prefix": "shared with SARS-CoV-1 (the virus that causes ",
#                 "exact": "SARS",
#                 "suffix": "), indicating that the epitope is highly",
#                 "offset": 5412,
#                 "length": 4
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/0d87e8a5-fb41-33c9-a1fb-bedf134b384e": {
#         "_typeGroup": "entities",
#         "_type": "Position",
#         "forenduserdisplay": "false",
#         "name": "President",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Position",
#         "instances": [
#             {
#                 "detection": "[second half of the year.\nMaya Martinez-Davis, ]President[, US Pharmaceuticals, GSK, said: \u201cWe are proud to]",
#                 "prefix": "second half of the year.\nMaya Martinez-Davis, ",
#                 "exact": "President",
#                 "suffix": ", US Pharmaceuticals, GSK, said: \u201cWe are proud to",
#                 "offset": 2198,
#                 "length": 9
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/8b8deb82-9beb-3c1d-924d-44774f059e91": {
#         "_typeGroup": "entities",
#         "_type": "Organization",
#         "forenduserdisplay": "false",
#         "name": "Biomedical Advanced Research and Development Authority",
#         "organizationtype": "governmental civilian",
#         "nationality": "N/A",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Organization",
#         "permid": "https://permid.org/1-404010",
#         "instances": [
#             {
#                 "detection": "[here in the US and around the world.\u201d\nThe ]Biomedical Advanced Research and Development Authority[ (BARDA), part of the Department of Health and]",
#                 "prefix": "here in the US and around the world.\u201d\nThe ",
#                 "exact": "Biomedical Advanced Research and Development Authority",
#                 "suffix": " (BARDA), part of the Department of Health and",
#                 "offset": 3297,
#                 "length": 54
#             },
#             {
#                 "detection": "[Advanced Research and Development Authority (]BARDA[), part of the Department of Health and Human]",
#                 "prefix": "Advanced Research and Development Authority (",
#                 "exact": "BARDA",
#                 "suffix": "), part of the Department of Health and Human",
#                 "offset": 3353,
#                 "length": 5
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/a54ac18b-a956-3b5c-b235-0609ca899305": {
#         "_typeGroup": "entities",
#         "_type": "Country",
#         "forenduserdisplay": "true",
#         "name": "United States",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Country",
#         "instances": [
#             {
#                 "detection": "[and Vir Biotechnology announce ]United States[ government agreement to purchase additional]",
#                 "prefix": "and Vir Biotechnology announce ",
#                 "exact": "United States",
#                 "suffix": " government agreement to purchase additional",
#                 "offset": 35,
#                 "length": 13
#             },
#             {
#                 "detection": "[only Issued: London, UK and San Francisco, ]US[\n600,000 additional doses to be supplied to the]",
#                 "prefix": "only Issued: London, UK and San Francisco, ",
#                 "exact": "US",
#                 "suffix": "\n600,000 additional doses to be supplied to the",
#                 "offset": 229,
#                 "length": 2
#             },
#             {
#                 "detection": "[additional doses to be supplied to the ]US[ Government for distribution in Q1 2022, enabling]",
#                 "prefix": "additional doses to be supplied to the ",
#                 "exact": "US",
#                 "suffix": " Government for distribution in Q1 2022, enabling",
#                 "offset": 279,
#                 "length": 2
#             },
#             {
#                 "detection": "[Inc. (Nasdaq: VIR) today announced that the ]US[ Government will purchase an additional 600,000]",
#                 "prefix": "Inc. (Nasdaq: VIR) today announced that the ",
#                 "exact": "US",
#                 "suffix": " Government will purchase an additional 600,000",
#                 "offset": 778,
#                 "length": 2
#             },
#             {
#                 "detection": "[to earlier commitments announced with the ]US[ Government in November 2021.\nIncluding the]",
#                 "prefix": "to earlier commitments announced with the ",
#                 "exact": "US",
#                 "suffix": " Government in November 2021.\nIncluding the",
#                 "offset": 1146,
#                 "length": 2
#             },
#             {
#                 "detection": "[agreement also includes the option for the ]US[ government to purchase further additional doses]",
#                 "prefix": "agreement also includes the option for the ",
#                 "exact": "US",
#                 "suffix": " government to purchase further additional doses",
#                 "offset": 1403,
#                 "length": 2
#             },
#             {
#                 "detection": "[ said: \u201cWe are proud to continue to work with the ]US[ government to bring sotrovimab to patients who]",
#                 "prefix": " said: \u201cWe are proud to continue to work with the ",
#                 "exact": "US",
#                 "suffix": " government to bring sotrovimab to patients who",
#                 "offset": 2283,
#                 "length": 2
#             },
#             {
#                 "detection": "[we are pleased to once again work with the ]US[ government to provide more access to sotrovimab]",
#                 "prefix": "we are pleased to once again work with the ",
#                 "exact": "US",
#                 "suffix": " government to provide more access to sotrovimab",
#                 "offset": 2836,
#                 "length": 2
#             },
#             {
#                 "detection": "[more access to sotrovimab for people in the ]US[ at high risk of progression to severe COVID-19.]",
#                 "prefix": "more access to sotrovimab for people in the ",
#                 "exact": "US",
#                 "suffix": " at high risk of progression to severe COVID-19.",
#                 "offset": 2905,
#                 "length": 2
#             },
#             {
#                 "detection": "[fight against the COVID-19 pandemic here in the ]US[ and around the world.\u201d\nThe Biomedical Advanced]",
#                 "prefix": "fight against the COVID-19 pandemic here in the ",
#                 "exact": "US",
#                 "suffix": " and around the world.\u201d\nThe Biomedical Advanced",
#                 "offset": 3267,
#                 "length": 2
#             }
#         ],
#         "relevance": 0.8,
#         "resolutions": [
#             {
#                 "name": "United States",
#                 "shortname": "United States",
#                 "latitude": "40.4230003233",
#                 "longitude": "-98.7372244786",
#                 "rcscode": "G:6J",
#                 "permid": "100319"
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/452d1bf0-2595-36cd-95ba-27e64a352f59": {
#         "_typeGroup": "entities",
#         "_type": "Position",
#         "forenduserdisplay": "false",
#         "name": "Assistant Secretary",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Position",
#         "instances": [
#             {
#                 "detection": "[of Health and Human Services (HHS) Office of ]the Assistant Secretary[ for Preparedness and Response (ASPR),]",
#                 "prefix": "of Health and Human Services (HHS) Office of ",
#                 "exact": "the Assistant Secretary",
#                 "suffix": " for Preparedness and Response (ASPR),",
#                 "offset": 3429,
#                 "length": 23
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/9567e05b-511e-3d06-8cf4-7f21c822f0b6": {
#         "_typeGroup": "entities",
#         "_type": "Position",
#         "forenduserdisplay": "false",
#         "name": "chief executive officer",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Position",
#         "instances": [
#             {
#                 "detection": "[more patients in 2022.\u201d\nGeorge Scangos, PhD, ]chief executive officer[ of Vir, said: \u201cAs the Omicron variant continues]",
#                 "prefix": "more patients in 2022.\u201d\nGeorge Scangos, PhD, ",
#                 "exact": "chief executive officer",
#                 "suffix": " of Vir, said: \u201cAs the Omicron variant continues",
#                 "offset": 2659,
#                 "length": 23
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/fb956cd8-8029-3233-aae8-837a0e68b393": {
#         "_typeGroup": "entities",
#         "_type": "Organization",
#         "forenduserdisplay": "false",
#         "name": "US Food and Drug Administration",
#         "organizationtype": "governmental civilian",
#         "nationality": "American",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Organization",
#         "permid": "https://permid.org/1-404010",
#         "instances": [
#             {
#                 "detection": "[ granted Emergency Use Authorization (EUA) by the ]US Food and Drug Administration[ (FDA) in May 2021, is an investigational]",
#                 "prefix": " granted Emergency Use Authorization (EUA) by the ",
#                 "exact": "US Food and Drug Administration",
#                 "suffix": " (FDA) in May 2021, is an investigational",
#                 "offset": 1556,
#                 "length": 31
#             },
#             {
#                 "detection": "[(EUA) by the US Food and Drug Administration (]FDA[) in May 2021, is an investigational single-dose]",
#                 "prefix": "(EUA) by the US Food and Drug Administration (",
#                 "exact": "FDA",
#                 "suffix": ") in May 2021, is an investigational single-dose",
#                 "offset": 1589,
#                 "length": 3
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/8ce83f41-24dd-36e0-9931-091e3dd0671a": {
#         "_typeGroup": "entities",
#         "_type": "Organization",
#         "forenduserdisplay": "false",
#         "name": "US Government",
#         "organizationtype": "governmental civilian",
#         "nationality": "American",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Organization",
#         "permid": "https://permid.org/1-404010",
#         "instances": [
#             {
#                 "detection": "[additional doses to be supplied to the ]US Government[ for distribution in Q1 2022, enabling further]",
#                 "prefix": "additional doses to be supplied to the ",
#                 "exact": "US Government",
#                 "suffix": " for distribution in Q1 2022, enabling further",
#                 "offset": 279,
#                 "length": 13
#             },
#             {
#                 "detection": "[Inc. (Nasdaq: VIR) today announced that the ]US Government[ will purchase an additional 600,000 doses of]",
#                 "prefix": "Inc. (Nasdaq: VIR) today announced that the ",
#                 "exact": "US Government",
#                 "suffix": " will purchase an additional 600,000 doses of",
#                 "offset": 778,
#                 "length": 13
#             },
#             {
#                 "detection": "[to earlier commitments announced with the ]US Government[ in November 2021.\nIncluding the commitments]",
#                 "prefix": "to earlier commitments announced with the ",
#                 "exact": "US Government",
#                 "suffix": " in November 2021.\nIncluding the commitments",
#                 "offset": 1146,
#                 "length": 13
#             },
#             {
#                 "detection": "[agreement also includes the option for the ]US government[ to purchase further additional doses in the]",
#                 "prefix": "agreement also includes the option for the ",
#                 "exact": "US government",
#                 "suffix": " to purchase further additional doses in the",
#                 "offset": 1403,
#                 "length": 13
#             },
#             {
#                 "detection": "[ said: \u201cWe are proud to continue to work with the ]US government[ to bring sotrovimab to patients who need it,]",
#                 "prefix": " said: \u201cWe are proud to continue to work with the ",
#                 "exact": "US government",
#                 "suffix": " to bring sotrovimab to patients who need it,",
#                 "offset": 2283,
#                 "length": 13
#             },
#             {
#                 "detection": "[we are pleased to once again work with the ]US government[ to provide more access to sotrovimab for people]",
#                 "prefix": "we are pleased to once again work with the ",
#                 "exact": "US government",
#                 "suffix": " to provide more access to sotrovimab for people",
#                 "offset": 2836,
#                 "length": 13
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/fa89cc40-abe1-3b21-814c-2ac35e370a7c": {
#         "_typeGroup": "entities",
#         "_type": "Organization",
#         "forenduserdisplay": "false",
#         "name": "Defense Joint Program Executive Office for Chemical",
#         "organizationtype": "governmental civilian",
#         "nationality": "N/A",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Organization",
#         "permid": "https://permid.org/1-404010",
#         "instances": [
#             {
#                 "detection": "[Department of Health and Human Services (HHS) ]Office[ of the Assistant Secretary for Preparedness and]",
#                 "prefix": "Department of Health and Human Services (HHS) ",
#                 "exact": "Office",
#                 "suffix": " of the Assistant Secretary for Preparedness and",
#                 "offset": 3419,
#                 "length": 6
#             },
#             {
#                 "detection": "[(ASPR), collaborated with the Department of ]Defense Joint Program Executive Office for Chemical[, Biological, Radiological and Nuclear Defense]",
#                 "prefix": "(ASPR), collaborated with the Department of ",
#                 "exact": "Defense Joint Program Executive Office for Chemical",
#                 "suffix": ", Biological, Radiological and Nuclear Defense",
#                 "offset": 3527,
#                 "length": 51
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/comphash-1/900ec64a-adfc-3c3b-8dc9-af9cb3b678b2": {
#         "_typeGroup": "entities",
#         "_type": "Company",
#         "forenduserdisplay": "true",
#         "name": "Xencor Inc.",
#         "nationality": "N/A",
#         "confidencelevel": "1.0",
#         "recognizedas": "name",
#         "resolutions": [
#             {
#                 "name": "XENCOR, INC.",
#                 "permid": "5000456188",
#                 "primaryric": "XNCR.OQ",
#                 "ispublic": "true",
#                 "commonname": "Xencor",
#                 "score": 1,
#                 "id": "https://permid.org/1-5000456188",
#                 "ticker": "XNCR"
#             }
#         ],
#         "confidence": {
#             "statisticalfeature": "0.823",
#             "dblookup": "0.0",
#             "resolution": "1.0",
#             "aggregate": "1.0"
#         },
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Company",
#         "instances": [
#             {
#                 "detection": "[to develop. Sotrovimab, which incorporates ]Xencor, Inc.[\u2019s Xtend\u2122 technology, has also been designed to]",
#                 "prefix": "to develop. Sotrovimab, which incorporates ",
#                 "exact": "Xencor, Inc.",
#                 "suffix": "\u2019s Xtend\u2122 technology, has also been designed to",
#                 "offset": 5559,
#                 "length": 12
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/comphash-1/dc75d048-9122-357d-b2f2-f9760d155e58": {
#         "_typeGroup": "entities",
#         "_type": "Company",
#         "forenduserdisplay": "true",
#         "name": "BIOMEDICAL ADVANCED RESEARCH AND DEVELOPMENT AUTHORITY",
#         "confidencelevel": "1.0",
#         "recognizedas": "name",
#         "resolutions": [
#             {
#                 "name": "Biomedical Advanced Research and Development Authority",
#                 "permid": "5064614947",
#                 "ispublic": "false",
#                 "commonname": "BARDA",
#                 "score": 1,
#                 "id": "https://permid.org/1-5064614947"
#             }
#         ],
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Company",
#         "instances": [
#             {
#                 "detection": "[here in the US and around the world.\u201d\nThe ]Biomedical Advanced Research and Development Authority[ (BARDA), part of the Department of Health and]",
#                 "prefix": "here in the US and around the world.\u201d\nThe ",
#                 "exact": "Biomedical Advanced Research and Development Authority",
#                 "suffix": " (BARDA), part of the Department of Health and",
#                 "offset": 3297,
#                 "length": 54
#             }
#         ],
#         "relevance": 0.2,
#         "confidence": {
#             "statisticalfeature": "0.715",
#             "dblookup": "0.0",
#             "resolution": "1.0",
#             "aggregate": "1.0"
#         }
#     },
#     "http://d.opencalais.com/comphash-1/9f7d3577-4050-38cf-b78d-290b4810bcaa": {
#         "_typeGroup": "entities",
#         "_type": "Company",
#         "forenduserdisplay": "true",
#         "name": "Vir Biotechnology Inc.",
#         "nationality": "N/A",
#         "confidencelevel": "1.0",
#         "recognizedas": "name",
#         "confidence": {
#             "statisticalfeature": "0.993",
#             "dblookup": "0.0",
#             "resolution": "1.0",
#             "aggregate": "1.0"
#         },
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Company",
#         "instances": [
#             {
#                 "detection": "[GSK and ]Vir Biotechnology[ announce United States government agreement to]",
#                 "prefix": "GSK and ",
#                 "exact": "Vir Biotechnology",
#                 "suffix": " announce United States government agreement to",
#                 "offset": 8,
#                 "length": 17
#             },
#             {
#                 "detection": "[Omicron\nGlaxoSmithKline plc (LSE/NYSE: GSK) and ]Vir Biotechnology, Inc. (Nasdaq: VIR)[ today announced that the US Government will]",
#                 "prefix": "Omicron\nGlaxoSmithKline plc (LSE/NYSE: GSK) and ",
#                 "exact": "Vir Biotechnology, Inc. (Nasdaq: VIR)",
#                 "suffix": " today announced that the US Government will",
#                 "offset": 715,
#                 "length": 37
#             },
#             {
#                 "detection": "[the commitments announced today, GSK and ]Vir[ have received binding agreements for the sale of]",
#                 "prefix": "the commitments announced today, GSK and ",
#                 "exact": "Vir",
#                 "suffix": " have received binding agreements for the sale of",
#                 "offset": 1229,
#                 "length": 3
#             },
#             {
#                 "detection": "[including hospitalisation or death.\nGSK and ]Vir[ expect to manufacture approximately 2 million]",
#                 "prefix": "including hospitalisation or death.\nGSK and ",
#                 "exact": "Vir",
#                 "suffix": " expect to manufacture approximately 2 million",
#                 "offset": 2033,
#                 "length": 3
#             },
#             {
#                 "detection": "[Scangos, PhD, chief executive officer of ]Vir[, said: \u201cAs the Omicron variant continues its]",
#                 "prefix": "Scangos, PhD, chief executive officer of ",
#                 "exact": "Vir",
#                 "suffix": ", said: \u201cAs the Omicron variant continues its",
#                 "offset": 2686,
#                 "length": 3
#             },
#             {
#                 "detection": "[and W58P0522C0002.\nIn June 2021, GSK and ]Vir[ announced confirmatory full results for the]",
#                 "prefix": "and W58P0522C0002.\nIn June 2021, GSK and ",
#                 "exact": "Vir",
#                 "suffix": " announced confirmatory full results for the",
#                 "offset": 3751,
#                 "length": 3
#             },
#             {
#                 "detection": "[2% and 1% of cases, respectively.\nGSK and ]Vir[ are committed to the ongoing evaluation of]",
#                 "prefix": "2% and 1% of cases, respectively.\nGSK and ",
#                 "exact": "Vir",
#                 "suffix": " are committed to the ongoing evaluation of",
#                 "offset": 4520,
#                 "length": 3
#             }
#         ],
#         "relevance": 0.8,
#         "resolutions": [
#             {
#                 "name": "VIR BIOTECHNOLOGY, INC.",
#                 "permid": "5052795509",
#                 "primaryric": "VIR.OQ",
#                 "ispublic": "true",
#                 "commonname": "Vir Biotech",
#                 "score": 1,
#                 "id": "https://permid.org/1-5052795509",
#                 "ticker": "VIR"
#             }
#         ]
#     },
#     "http://d.opencalais.com/pershash-1/d27cc703-5b4c-3d24-a7bb-6b10bba690cc": {
#         "_typeGroup": "entities",
#         "_type": "Person",
#         "forenduserdisplay": "true",
#         "middlename": "Martinez",
#         "firstname": "Maya",
#         "confidencelevel": "0.95",
#         "persontype": "N/A",
#         "name": "Maya Martinez-Davis",
#         "nationality": "N/A",
#         "lastname": "Davis",
#         "commonname": "Maya Martinez-Davis",
#         "confidence": {
#             "statisticalfeature": "0.97",
#             "dblookup": "0.0",
#             "resolution": "0.0",
#             "aggregate": "0.95"
#         },
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Person",
#         "permid": "https://permid.org/1-404011",
#         "instances": [
#             {
#                 "detection": "[ additional doses in the second half of the year.\n]Maya Martinez-Davis[, President, US Pharmaceuticals, GSK, said: \u201cWe]",
#                 "prefix": " additional doses in the second half of the year.\n",
#                 "exact": "Maya Martinez-Davis",
#                 "suffix": ", President, US Pharmaceuticals, GSK, said: \u201cWe",
#                 "offset": 2177,
#                 "length": 19
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/cc88b155-205c-3676-a151-d45f473f0b16": {
#         "_typeGroup": "entities",
#         "_type": "Country",
#         "forenduserdisplay": "true",
#         "name": "United Kingdom",
#         "resolutions": [
#             {
#                 "name": "United Kingdom",
#                 "shortname": "United Kingdom",
#                 "latitude": "53.1142456495",
#                 "longitude": "-2.57711368423",
#                 "rcscode": "G:7J",
#                 "permid": "100317"
#             }
#         ],
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Country",
#         "instances": [
#             {
#                 "detection": "[media and investors only Issued: London, ]UK[ and San Francisco, US\n600,000 additional doses]",
#                 "prefix": "media and investors only Issued: London, ",
#                 "exact": "UK",
#                 "suffix": " and San Francisco, US\n600,000 additional doses",
#                 "offset": 207,
#                 "length": 2
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/6fda72fd-105c-39ba-bb79-da95785a249f": {
#         "_typeGroup": "entities",
#         "_type": "City",
#         "forenduserdisplay": "true",
#         "name": "London",
#         "resolutions": [
#             {
#                 "name": "London,Greater London,United Kingdom",
#                 "shortname": "London",
#                 "latitude": "51.517124",
#                 "longitude": "-0.106196",
#                 "containedbystate": "Greater London",
#                 "containedbycountry": "United Kingdom",
#                 "rcscode": "G:21P"
#             }
#         ],
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/City",
#         "instances": [
#             {
#                 "detection": "[ of COVID-19\nFor media and investors only Issued: ]London[, UK and San Francisco, US\n600,000 additional]",
#                 "prefix": " of COVID-19\nFor media and investors only Issued: ",
#                 "exact": "London",
#                 "suffix": ", UK and San Francisco, US\n600,000 additional",
#                 "offset": 199,
#                 "length": 6
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/ff6780df-d037-3b21-a5cc-bd9e6ee5727e": {
#         "_typeGroup": "entities",
#         "_type": "MedicalCondition",
#         "forenduserdisplay": "false",
#         "name": "hypersensitivity",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/MedicalCondition",
#         "instances": [
#             {
#                 "detection": "[The most common adverse reactions are ]hypersensitivity[ and infusion-related reactions, seen in]",
#                 "prefix": "The most common adverse reactions are ",
#                 "exact": "hypersensitivity",
#                 "suffix": " and infusion-related reactions, seen in",
#                 "offset": 4407,
#                 "length": 16
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/a5eb86f7-b71a-3d98-b719-bff0f8ecd2a3": {
#         "_typeGroup": "entities",
#         "_type": "Organization",
#         "forenduserdisplay": "false",
#         "name": "Department of Health and Human Services",
#         "organizationtype": "governmental civilian",
#         "nationality": "N/A",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Organization",
#         "permid": "https://permid.org/1-404010",
#         "instances": [
#             {
#                 "detection": "[and Development Authority (BARDA), part of the ]Department of Health and Human Services[ (HHS) Office of the Assistant Secretary for]",
#                 "prefix": "and Development Authority (BARDA), part of the ",
#                 "exact": "Department of Health and Human Services",
#                 "suffix": " (HHS) Office of the Assistant Secretary for",
#                 "offset": 3373,
#                 "length": 39
#             },
#             {
#                 "detection": "[of the Department of Health and Human Services (]HHS[) Office of the Assistant Secretary for]",
#                 "prefix": "of the Department of Health and Human Services (",
#                 "exact": "HHS",
#                 "suffix": ") Office of the Assistant Secretary for",
#                 "offset": 3414,
#                 "length": 3
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/pershash-1/cb32c1a5-31c8-3848-8c9f-3d5bf5c6dbf1": {
#         "_typeGroup": "entities",
#         "_type": "Person",
#         "forenduserdisplay": "true",
#         "nationality": "N/A",
#         "name": "George Scangos",
#         "confidencelevel": "0.975",
#         "firstname": "George",
#         "persontype": "N/A",
#         "lastname": "Scangos",
#         "commonname": "George Scangos",
#         "confidence": {
#             "statisticalfeature": "0.97",
#             "dblookup": "0.0",
#             "resolution": "0.86259556",
#             "aggregate": "0.975"
#         },
#         "resolutions": [
#             {
#                 "name": "George A. Scangos",
#                 "personid": "2003065",
#                 "paid": "34415554822",
#                 "officerid": "2852905",
#                 "commonname": "George Scangos",
#                 "score": 0.86259556
#             }
#         ],
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Person",
#         "permid": "https://permid.org/1-404011",
#         "instances": [
#             {
#                 "detection": "[so we can support more patients in 2022.\u201d\n]George Scangos[, PhD, chief executive officer of Vir, said: \u201cAs]",
#                 "prefix": "so we can support more patients in 2022.\u201d\n",
#                 "exact": "George Scangos",
#                 "suffix": ", PhD, chief executive officer of Vir, said: \u201cAs",
#                 "offset": 2638,
#                 "length": 14
#             }
#         ],
# ...
#                 "offset": 2209,
#                 "length": 18
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/e678ca1c-7da6-32bd-bd26-f1bce4cfab91": {
#         "_typeGroup": "entities",
#         "_type": "Organization",
#         "forenduserdisplay": "false",
#         "name": "United States government",
#         "organizationtype": "governmental civilian",
#         "nationality": "American",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Organization",
#         "permid": "https://permid.org/1-404010",
#         "instances": [
#             {
#                 "detection": "[and Vir Biotechnology announce ]United States government[ agreement to purchase additional supply of]",
#                 "prefix": "and Vir Biotechnology announce ",
#                 "exact": "United States government",
#                 "suffix": " agreement to purchase additional supply of",
#                 "offset": 35,
#                 "length": 24
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/12828997-611c-3f39-8e00-761262fc611a": {
#         "_typeGroup": "entities",
#         "_type": "Product",
#         "forenduserdisplay": "false",
#         "name": "COVID-19",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Product",
#         "instances": [
#             {
#                 "detection": "[for early treatment of mild-to-moderate ]COVID-19[ in high-risk, non-hospitalised adults. The trial]",
#                 "prefix": "for early treatment of mild-to-moderate ",
#                 "exact": "COVID-19",
#                 "suffix": " in high-risk, non-hospitalised adults. The trial",
#                 "offset": 3893,
#                 "length": 8
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/978e4354-97d1-3f13-9bc1-0d5547e2a55e": {
#         "_typeGroup": "entities",
#         "_type": "Product",
#         "forenduserdisplay": "false",
#         "name": "CoV-2",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Product",
#         "instances": [
#             {
#                 "detection": "[single-dose intravenous (IV) infusion SARS-]CoV-2[ monoclonal antibody. Under the EUA, sotrovimab]",
#                 "prefix": "single-dose intravenous (IV) infusion SARS-",
#                 "exact": "CoV-2",
#                 "suffix": " monoclonal antibody. Under the EUA, sotrovimab",
#                 "offset": 1672,
#                 "length": 5
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/d04d767d-02a0-3480-b872-41e765ae181d": {
#         "_typeGroup": "relations",
#         "_type": "Quotation",
#         "forenduserdisplay": "true",
#         "quotation": "\u201cAs the Omicron variant continues its rapid spread alongside the still prevalent Delta variant, we are pleased to once again work with the US government to provide more access to sotrovimab for people in the US at high risk of progression to severe COVID-19",
#         "quotationtype": "Paraphrase",
#         "_typeReference": "http://s.opencalais.com/1/type/em/r/Quotation",
#         "speaker": "http://d.opencalais.com/pershash-1/cb32c1a5-31c8-3848-8c9f-3d5bf5c6dbf1",
#         "instances": [
#             {
#                 "detection": "[to grow in prevalence across the country. ]We understand the role we can play in supporting the ongoing pandemic response, and our teams are working with urgency to explore options to expand our supply capacity so we can support more patients in 2022.\u201d\nGeorge Scangos, PhD, chief executive officer of Vir, said: \u201cAs the Omicron variant continues its rapid spread alongside the still prevalent Delta variant, we are pleased to once again work with the US government to provide more access to sotrovimab for people in the US at high risk of progression to severe COVID-19.[ Data from multiple pseudo-virus and live virus]",
#                 "prefix": "to grow in prevalence across the country. ",
#                 "exact": "We understand the role we can play in supporting the ongoing pandemic response, and our teams are working with urgency to explore options to expand our supply capacity so we can support more patients in 2022.\u201d\nGeorge Scangos, PhD, chief executive officer of Vir, said: \u201cAs the Omicron variant continues its rapid spread alongside the still prevalent Delta variant, we are pleased to once again work with the US government to provide more access to sotrovimab for people in the US at high risk of progression to severe COVID-19.",
#                 "suffix": " Data from multiple pseudo-virus and live virus",
#                 "offset": 2428,
#                 "length": 527
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/24738f5a-53fd-36eb-9afc-c6fd5474a5e2": {
#         "_typeGroup": "relations",
#         "_type": "Quotation",
#         "forenduserdisplay": "true",
#         "quotation": "the US Government will purchase an additional 600,000 doses of sotrovimab, an investigational monoclonal antibody for the early treatment of COVID-19, enabling further nationwide access to sotrovimab for patients.",
#         "quotationtype": "Paraphrase",
#         "_typeReference": "http://s.opencalais.com/1/type/em/r/Quotation",
#         "speaker": "http://d.opencalais.com/comphash-1/9f7d3577-4050-38cf-b78d-290b4810bcaa",
#         "instances": [
#             {
#                 "detection": "[GSK) and Vir Biotechnology, Inc. (Nasdaq: ]VIR) today announced that the US Government will purchase an additional 600,000 doses of sotrovimab, an investigational monoclonal antibody for the early treatment of COVID-19, enabling further nationwide access to sotrovimab for patients.[ The additional 600,000 doses will be delivered]",
#                 "prefix": "GSK) and Vir Biotechnology, Inc. (Nasdaq: ",
#                 "exact": "VIR) today announced that the US Government will purchase an additional 600,000 doses of sotrovimab, an investigational monoclonal antibody for the early treatment of COVID-19, enabling further nationwide access to sotrovimab for patients.",
#                 "suffix": " The additional 600,000 doses will be delivered",
#                 "offset": 748,
#                 "length": 239
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/28c9d3f1-6a71-3da8-abe0-ad4855ad255d": {
#         "_typeGroup": "relations",
#         "_type": "FDAPhase",
#         "forenduserdisplay": "false",
#         "fdastage": "Approval",
#         "status": "NA",
#         "producttype": "drug",
#         "_typeReference": "http://s.opencalais.com/1/type/em/r/FDAPhase",
#         "company": "http://d.opencalais.com/comphash-1/9f7d3577-4050-38cf-b78d-290b4810bcaa",
#         "product": "http://d.opencalais.com/genericHasher-1/978e4354-97d1-3f13-9bc1-0d5547e2a55e",
#         "instances": [
#             {
#                 "detection": "[second quarter of 2022.\nSotrovimab, which was ]granted Emergency Use Authorization (EUA) by the US Food and Drug Administration (FDA) in May 2021, is an investigational single-dose intravenous (IV) infusion SARS-CoV-2[ monoclonal antibody. Under the EUA, sotrovimab]",
#                 "prefix": "second quarter of 2022.\nSotrovimab, which was ",
#                 "exact": "granted Emergency Use Authorization (EUA) by the US Food and Drug Administration (FDA) in May 2021, is an investigational single-dose intravenous (IV) infusion SARS-CoV-2",
#                 "suffix": " monoclonal antibody. Under the EUA, sotrovimab",
#                 "offset": 1507,
#                 "length": 170
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/01164f09-f10e-3cbb-8835-1ffe279b3cf6": {
#         "_typeGroup": "relations",
#         "_type": "CompanyLaborIssues",
#         "forenduserdisplay": "false",
#         "_typeReference": "http://s.opencalais.com/1/type/em/r/CompanyLaborIssues",
#         "company": "http://d.opencalais.com/comphash-1/9f7d3577-4050-38cf-b78d-290b4810bcaa",
#         "instances": [
#             {
#                 "detection": "[]GSK and Vir Biotechnology announce United States government agreement[ to purchase additional supply of sotrovimab,]",
#                 "exact": "GSK and Vir Biotechnology announce United States government agreement",
#                 "suffix": " to purchase additional supply of sotrovimab,",
#                 "offset": 0,
#                 "length": 69
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/cb13a027-5bdf-3473-9f12-e8de94451a11": {
#         "_typeGroup": "relations",
#         "_type": "Quotation",
#         "forenduserdisplay": "true",
#         "quotation": "\u201cWe are proud to continue to work with the US government to bring sotrovimab to patients who need it, especially as the Omicron variant continues to grow in prevalence across the country",
#         "quotationtype": "Paraphrase",
#         "_typeReference": "http://s.opencalais.com/1/type/em/r/Quotation",
#         "speaker": "http://d.opencalais.com/pershash-1/d27cc703-5b4c-3d24-a7bb-6b10bba690cc",
#         "instances": [
#             {
#                 "detection": "[ additional doses in the second half of the year.\n]Maya Martinez-Davis, President, US Pharmaceuticals, GSK, said: \u201cWe are proud to continue to work with the US government to bring sotrovimab to patients who need it, especially as the Omicron variant continues to grow in prevalence across the country.[ We understand the role we can play in supporting]",
#                 "prefix": " additional doses in the second half of the year.\n",
#                 "exact": "Maya Martinez-Davis, President, US Pharmaceuticals, GSK, said: \u201cWe are proud to continue to work with the US government to bring sotrovimab to patients who need it, especially as the Omicron variant continues to grow in prevalence across the country.",
#                 "suffix": " We understand the role we can play in supporting",
#                 "offset": 2177,
#                 "length": 250
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/141f5350-4c29-34f4-b2d5-469c6f17e83d": {
#         "_typeGroup": "relations",
#         "_type": "PersonCareer",
#         "forenduserdisplay": "true",
#         "position": "chief executive officer",
#         "careertype": "professional",
#         "status": "current",
#         "_typeReference": "http://s.opencalais.com/1/type/em/r/PersonCareer",
#         "person": "http://d.opencalais.com/pershash-1/cb32c1a5-31c8-3848-8c9f-3d5bf5c6dbf1",
#         "company": "http://d.opencalais.com/comphash-1/9f7d3577-4050-38cf-b78d-290b4810bcaa",
#         "instances": [
#             {
#                 "detection": "[so we can support more patients in 2022.\u201d\n]George Scangos, PhD, chief executive officer of Vir[, said: \u201cAs the Omicron variant continues its]",
#                 "prefix": "so we can support more patients in 2022.\u201d\n",
#                 "exact": "George Scangos, PhD, chief executive officer of Vir",
#                 "suffix": ", said: \u201cAs the Omicron variant continues its",
#                 "offset": 2638,
#                 "length": 51
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/22c288c5-098a-3de3-8cc2-6ba54a77cfa7": {
#         "_typeGroup": "relations",
#         "_type": "PersonCareer",
#         "forenduserdisplay": "true",
#         "position": "President",
#         "careertype": "professional",
#         "status": "current",
#         "_typeReference": "http://s.opencalais.com/1/type/em/r/PersonCareer",
#         "person": "http://d.opencalais.com/pershash-1/d27cc703-5b4c-3d24-a7bb-6b10bba690cc",
#         "company": "http://d.opencalais.com/comphash-1/aca3af83-1cfd-34dc-8204-a5438b7efb4a",
#         "instances": [
#             {
#                 "detection": "[ additional doses in the second half of the year.\n]Maya Martinez-Davis, President, US Pharmaceuticals[, GSK, said: \u201cWe are proud to continue to work]",
#                 "prefix": " additional doses in the second half of the year.\n",
#                 "exact": "Maya Martinez-Davis, President, US Pharmaceuticals",
#                 "suffix": ", GSK, said: \u201cWe are proud to continue to work",
#                 "offset": 2177,
#                 "length": 50
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/ca4f84b9-0543-3de6-9043-ff9ca9e63042": {
#         "_typeGroup": "relations",
#         "_type": "CompanyTicker",
#         "forenduserdisplay": "false",
#         "ticker": "VIR",
#         "stockexchange": "NASDAQ",
#         "_typeReference": "http://s.opencalais.com/1/type/em/r/CompanyTicker",
#         "company": "http://d.opencalais.com/comphash-1/9f7d3577-4050-38cf-b78d-290b4810bcaa",
#         "instances": [
#             {
#                 "detection": "[Omicron\nGlaxoSmithKline plc (LSE/NYSE: GSK) and ]Vir Biotechnology, Inc. (Nasdaq: VIR)[ today announced that the US Government will]",
#                 "prefix": "Omicron\nGlaxoSmithKline plc (LSE/NYSE: GSK) and ",
#                 "exact": "Vir Biotechnology, Inc. (Nasdaq: VIR)",
#                 "suffix": " today announced that the US Government will",
#                 "offset": 715,
#                 "length": 37
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/a210b28f-71e5-3ea5-b318-eac413fad76f": {
#         "_typeGroup": "relations",
#         "_type": "Quotation",
#         "forenduserdisplay": "true",
#         "quotation": "confirmatory full results for the COMET-ICE Phase III trial examining use of sotrovimab for early treatment of mild-to-moderate COVID-19 in high-risk, non-hospitalised adults",
#         "quotationtype": "Paraphrase",
#         "_typeReference": "http://s.opencalais.com/1/type/em/r/Quotation",
#         "speaker": "http://d.opencalais.com/comphash-1/9f7d3577-4050-38cf-b78d-290b4810bcaa",
#         "instances": [
#             {
#                 "detection": "[numbers W58P0521C0008 and W58P0522C0002.\n]In June 2021, GSK and Vir announced confirmatory full results for the COMET-ICE Phase III trial examining use of sotrovimab for early treatment of mild-to-moderate COVID-19 in high-risk, non-hospitalised adults.[ The trial met the primary endpoint with a 79%]",
#                 "prefix": "numbers W58P0521C0008 and W58P0522C0002.\n",
#                 "exact": "In June 2021, GSK and Vir announced confirmatory full results for the COMET-ICE Phase III trial examining use of sotrovimab for early treatment of mild-to-moderate COVID-19 in high-risk, non-hospitalised adults.",
#                 "suffix": " The trial met the primary endpoint with a 79%",
#                 "offset": 3729,
#                 "length": 211
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/23cdf20a-0104-31b6-a758-96dfc324bcc6": {
#         "_typeGroup": "relations",
#         "_type": "FDAPhase",
#         "forenduserdisplay": "false",
#         "fdastage": "Phase 3 Trial",
#         "status": "NA",
#         "producttype": "drug",
#         "_typeReference": "http://s.opencalais.com/1/type/em/r/FDAPhase",
#         "company": "http://d.opencalais.com/comphash-1/3fe4d011-ec03-3a20-9bbd-cae499ca99e8",
#         "product": "http://d.opencalais.com/genericHasher-1/12828997-611c-3f39-8e00-761262fc611a",
#         "instances": [
#             {
#                 "detection": "[W58P0521C0008 and W58P0522C0002.\nIn June 2021, ]GSK and Vir announced confirmatory full results for the COMET-ICE Phase III trial examining use of sotrovimab for early treatment of mild-to-moderate COVID-19[ in high-risk, non-hospitalised adults. The trial]",
#                 "prefix": "W58P0521C0008 and W58P0522C0002.\nIn June 2021, ",
#                 "exact": "GSK and Vir announced confirmatory full results for the COMET-ICE Phase III trial examining use of sotrovimab for early treatment of mild-to-moderate COVID-19",
#                 "suffix": " in high-risk, non-hospitalised adults. The trial",
#                 "offset": 3743,
#                 "length": 158
#             }
#         ]
#     }
# }

# %%
res = TRITResponse.json()

# %%
#import json
#import pandas as pd

# Load the JSON data 
#file_path = "/mnt/data/updatedtest.json"
#with open(file_path, "r", encoding="utf-8") as file:
#    data = json.load(file)

# Prepare lists to collect categorized entries
socialtags = []
industries = []
companies = []
persons = []
topics =[]

# Categorize based on _typeGroup and _type
for key, value in res.items():
    if value.get("_typeGroup") == "socialTag":
        socialtags.append(value)
    elif value.get("_typeGroup") == "industry":
        industries.append(value)
    elif value.get("_typeGroup") == "topics":
        topics.append(value)
    elif value.get("_typeGroup") == "entities":
        if value.get("_type") == "Company":
            companies.append(value)
        elif value.get("_type") == "Person":
            persons.append(value)

# Convert each list into a DataFrame
df_socialtags = pd.DataFrame(socialtags)
df_industries = pd.DataFrame(industries)
df_companies = pd.DataFrame(companies)
df_persons = pd.DataFrame(persons)
df_topics = pd.DataFrame(topics)

# %%
def pretty_print(df, col_widths=None, headers=True):
    """
    Pretty-print a pandas DataFrame with left-aligned columns in the console.

    Args:
        df (pd.DataFrame): The DataFrame to print.
        col_widths (dict): Optional dict to set column widths. Example: {'name': 30, 'importance': 10}
        headers (bool): Whether to print headers or not.
    """
    if col_widths is None:
        # Default widths: auto-set based on longest entry in each column or 15
        col_widths = {
            col: max(df[col].astype(str).map(len).max(), len(str(col)), 15)
            for col in df.columns
        }

    # Format string builder
    fmt = "  ".join([f"{{:<{col_widths[col]}}}" for col in df.columns])

    # Print headers
    if headers:
        print(fmt.format(*df.columns))
        print("-" * (sum(col_widths.values()) + 2 * (len(col_widths) - 1)))

    # Print rows
    for _, row in df.iterrows():
        print(fmt.format(*[str(row[col]) for col in df.columns]))

# %%
#print(df_socialtags)

# Extract only the 'name','importance' field from social tags
df_socialtags_filtered = df_socialtags[['name', 'importance']].sort_values(by=['importance'],ascending=True)


#df_socialtagssorted = df_socialtags_filtered.sort_values(by=['importance'], ascending=False)
#tools.display_dataframe_to_user(name="Filtered SocialTags", dataframe=df_socialtags_filtered)
#print(df_socialtags_filtered.to_string(index=False,justify='left'))

pretty_print(df_socialtags_filtered)
# Out:
# name                            importance
# -----------------------------------------------
# COVID-19 drug development       1
# Monoclonal antibodies           1
# Occupational safety and health  1
# Sotrovimab                      2
# SARS-CoV-2 Omicron variant      2
# SARS-CoV-2 Delta variant        2
# COVID-19 pandemic               2
# Variants of SARS-CoV-2          2
# SARS-CoV-2 Mu variant           2
# COVID-19                        2
# SARS-CoV-2                      2
# Coronavirus spike protein       2

# %%
# Extract 'name', 'permid', 'relevance' fields from industries
df_industries_filtered = df_industries[['name', 'permid', 'relevance']].sort_values(by=['relevance'],ascending=False)

#tools.display_dataframe_to_user(name="Filtered Industries", dataframe=df_industries_filtered)
#print(df_industries_filtered.to_string(index=False,justify='left'))

pretty_print(df_industries_filtered)
# Out:
# name                                    permid           relevance
# ------------------------------------------------------------------------
# Biotechnology & Medical Research (NEC)  4294951265       0.8
# Government Administration Activities    1004365576       0.5
# Government & Government Finance (NEC)   1004365552       0.2
# Bio Therapeutic Drugs                   4294951264       0.2
# Pharmaceuticals (NEC)                   4294951272       0.2

# %%
company_data = []

for company in companies:
    name = company.get("name")
    relevance = company.get("relevance")
    resolutions = company.get("resolutions", [])

    # Default permid is None unless we find one
    permid = None
    if isinstance(resolutions, list) and len(resolutions) > 0:
        permid = resolutions[0].get("permid")

    company_data.append({
        "name": name,
        "permid": permid,
        "relevance": relevance
    })

# Create a DataFrame from the cleaned-up list
df_company_resolved = pd.DataFrame(company_data).sort_values(by=['relevance'],ascending=False)

#print(df_company_resolved)
pretty_print(df_company_resolved)
# Out:
# name                                                    permid           relevance
# ----------------------------------------------------------------------------------------
# Vir Biotechnology Inc.                                  5052795509       0.8
# US FOOD AND DRUG ADMINISTRATION                         8589934550       0.5
# BIOMEDICAL ADVANCED RESEARCH AND DEVELOPMENT AUTHORITY  5064614947       0.2
# Xencor Inc.                                             5000456188       0.2
# GLAXOSMITHKLINE PLC                                     4295895781       0.2
# US Pharmaceuticals                                      4296883011       0.2

# %%
company_resolutions = []

for company in companies:
    name = company.get("name")
    relevance = company.get("relevance")
    confidence_level = company.get("confidencelevel")
    confidence_agg = company.get("confidence", {}).get("aggregate")

    resolutions = company.get("resolutions")

    if resolutions and isinstance(resolutions, list):
        # One row per resolution
        for res in resolutions:
            company_resolutions.append({
                "name": name,
                "relevance": relevance,
                "confidence_level": confidence_level,
                #"confidence_aggregate": confidence_agg,
                "permid": res.get("permid"),
                "RIC": res.get("primaryric"),
                "resolution_score": res.get("score")
            })
    else:  #This part is to handle if no resolutions present. Remove if necessary/still add the company info, with null resolution fields
        company_resolutions.append({
            "name": name,
            "relevance": relevance,
            "confidence_level": confidence_level,
            #"confidence_aggregate": confidence_agg,
            "permid": None,
            "RIC": None,
            "resolution_score": None
        })

df_company_resolutions = pd.DataFrame(company_resolutions).sort_values(by=['relevance'],ascending=False)
pretty_print(df_company_resolutions)
# Out:
# name                                                    relevance        confidence_level  permid           RIC              resolution_score
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Vir Biotechnology Inc.                                  0.8              1.0               5052795509       VIR.OQ           1.0
# US FOOD AND DRUG ADMINISTRATION                         0.5              1.0               8589934550       None             1.0
# BIOMEDICAL ADVANCED RESEARCH AND DEVELOPMENT AUTHORITY  0.2              1.0               5064614947       None             1.0
# Xencor Inc.                                             0.2              1.0               5000456188       XNCR.OQ          1.0
# GLAXOSMITHKLINE PLC                                     0.2              1.0               4295895781       GSK.L            0.5524654
# US Pharmaceuticals                                      0.2              0.552             4296883011       None             0.11083034

# %%
# Extract only the 'name' field from person tags

person_resolutions = []

for person in persons:
    name = person.get("name")
    relevance = person.get("relevance")
    confidence_level = person.get("confidencelevel")
    confidence_agg = person.get("confidence", {}).get("aggregate")

    resolutions = person.get("resolutions")

    if resolutions and isinstance(resolutions, list):
        # One row per resolution
        for res in resolutions:
            person_resolutions.append({
                "name": name,
                "relevance": relevance,
                "confidence_level": confidence_level,
                #"confidence_aggregate": confidence_agg,
                "permid": res.get("paid"),
                "resolution_score": res.get("score")
            })
    else:
        # No resolutions — still add the person info, with null resolution fields
        person_resolutions.append({
            "name": name,
            "relevance": relevance,
            "confidence_level": confidence_level,
            #"confidence_aggregate": confidence_agg,
            "permid": None,
            "resolution_score": None
        })

df_person_resolutions = pd.DataFrame(person_resolutions).sort_values(by=['relevance'],ascending=False)
pretty_print(df_person_resolutions)
# Out:
# name                 relevance        confidence_level  permid           resolution_score
# -----------------------------------------------------------------------------------------
# Maya Martinez-Davis  0.2              0.95              None             nan
# George Scangos       0.2              0.975             34415554822      0.86259556

# %%
# Extract only the 'name' field from topic tags
df_topics_filtered = df_topics[['name','permid', 'score']].sort_values(by=['score'],ascending=False)

#tools.display_dataframe_to_user(name="Filtered SocialTags", dataframe=df_topic_filtered)
#print(df_topics_filtered)
pretty_print(df_topics_filtered)
# Out:
# name                                       permid           score
# ---------------------------------------------------------------------------
# Health_Medical_Pharma                      nan              1.0
# Health / Medicine                          400672           1.0
# M_3C1                                      nan              0.963
# Press Releases                             1004026377       0.948
# Business_Finance                           nan              0.85
# Science                                    201099           0.761
# Pharmaceuticals & Medical Research (TRBC)  4294952845       0.724
# Drug & Device Development                  386025           0.527
# Public Health                              386041           0.375
