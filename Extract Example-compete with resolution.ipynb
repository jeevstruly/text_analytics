# %%
import requests
import json
import os
import dotenv
import pandas as pd

# %%
print("Current Working Directory:",(os.getcwd()))
# Out:
# Current Working Directory: c:\Users\RJR-AS\Documents\TextAnalyticsVS\text_analytics

# %%
contentText3="""Thor Steel is introducing a new vibranium bread in the market. Thor Steel is new to the bread market. The bread launch will take place in stages, leading up to summer 2025. Thor Steel CEO, Bruce Banner, will be speaking more about the launch at Thor Steel shareholder lunch and launch. There are around 63 firm orders for the upcoming Airbus A350F based on the Airbus A350-900 passenger aircraft. The aircraft had been expected to enter service in 2026, but that has now been pushed back to 2027. Still, expectations are high for the Airbus A350F . Currently, the world is looking forward to the introduction of two new freighters, the Boeing 777X freighter and the Airbus A350F.
The A350 has proven a popular platform and one that is well adapted to being used as a freighter. This is in contrast with the Airbus A380, which is poorly designed to function as a freighter. Here is what to know about the orders for the Airbus A350F.

Airbus A350F orders
Ch-aviation lists that over nine customers have so far ordered 66 Airbus A350F cargo aircraft."""


contentText2 = """GSK and Vir Biotechnology announce United States government agreement to purchase additional supply of sotrovimab, authorised for the early treatment of COVID-19
For media and investors only Issued: London, UK and San Francisco, US
600,000 additional doses to be supplied to the US Government for distribution in Q1 2022, enabling further access to sotrovimab nationwide
Brings total number of doses secured to date through binding agreements to approximately 1.7 million globally
Preclinical data generated through both pseudo-virus and live virus testing demonstrate sotrovimab retains activity against all tested SARS-CoV-2 variants of concern including Delta and Omicron
GlaxoSmithKline plc (LSE/NYSE: GSK) and Vir Biotechnology, Inc. (Nasdaq: VIR) today announced that the US Government will purchase an additional 600,000 doses of sotrovimab, an investigational monoclonal antibody for the early treatment of COVID-19, enabling further nationwide access to sotrovimab for patients. The additional 600,000 doses will be delivered throughout the first quarter of 2022. This agreement is an amendment to earlier commitments announced with the US Government in November 2021.
Including the commitments announced today, GSK and Vir have received binding agreements for the sale of approximately 1.7 million doses of sotrovimab worldwide. In addition, today’s agreement also includes the option for the US government to purchase further additional doses in the second quarter of 2022.
Sotrovimab, which was granted Emergency Use Authorization (EUA) by the US Food and Drug Administration (FDA) in May 2021, is an investigational single-dose intravenous (IV) infusion SARS-CoV-2 monoclonal antibody. Under the EUA, sotrovimab can be used for the treatment of mild-to-moderate COVID-19 in adults and paediatric patients (12 years of age and older weighing at least 40 kg) with positive results of direct SARS-CoV-2 viral testing, and who are at high risk for progression to severe COVID-19, including hospitalisation or death.
GSK and Vir expect to manufacture approximately 2 million doses globally in the first half of 2022 and additional doses in the second half of the year.
Maya Martinez-Davis, President, US Pharmaceuticals, GSK, said: “We are proud to continue to work with the US government to bring sotrovimab to patients who need it, especially as the Omicron variant continues to grow in prevalence across the country. We understand the role we can play in supporting the ongoing pandemic response, and our teams are working with urgency to explore options to expand our supply capacity so we can support more patients in 2022.”
George Scangos, PhD, chief executive officer of Vir, said: “As the Omicron variant continues its rapid spread alongside the still prevalent Delta variant, we are pleased to once again work with the US government to provide more access to sotrovimab for people in the US at high risk of progression to severe COVID-19. Data from multiple pseudo-virus and live virus preclinical studies, generated by industry and academia, continue to demonstrate that sotrovimab retains activity against all tested variants of concern and interest. We are proud of our ongoing contributions to the fight against the COVID-19 pandemic here in the US and around the world.”
The Biomedical Advanced Research and Development Authority (BARDA), part of the Department of Health and Human Services (HHS) Office of the Assistant Secretary for Preparedness and Response (ASPR), collaborated with the Department of Defense Joint Program Executive Office for Chemical, Biological, Radiological and Nuclear Defense (JPEO-CBRND) and Army Contracting Command to purchase contract numbers W58P0521C0008 and W58P0522C0002.
In June 2021, GSK and Vir announced confirmatory full results for the COMET-ICE Phase III trial examining use of sotrovimab for early treatment of mild-to-moderate COVID-19 in high-risk, non-hospitalised adults. The trial met the primary endpoint with a 79% reduction (adjusted relative risk reduction) (p<0.001) in all-cause hospitalisations for more than 24 hours or death due to any cause by Day 29 compared to placebo. In absolute numbers, 30 (6%) of the 529 patients in the placebo arm progressed, compared to six (1%) of the 528 patients receiving sotrovimab. In clinical trials conducted to date, sotrovimab has been well-tolerated. The most common adverse reactions are hypersensitivity and infusion-related reactions, seen in approximately 2% and 1% of cases, respectively.
GSK and Vir are committed to the ongoing evaluation of sotrovimab as the COVID-19 landscape continues to evolve at different rates across the globe and new variants of concern and interest emerge. Preclinical pseudo-virus data, published in bioRxiv, demonstrate that sotrovimab retains activity against all tested variants of concern and interest of the SARS-CoV-2 virus as defined by the World Health Organization, including, but not limited to, Omicron (B.1.1.529), Delta (B.1.617.2), Delta Plus (AY.1 or AY.2) and Mu (B.1.621). Preclinical live virus testing has also been completed with data, recently published in bioRxiv, further demonstrating that sotrovimab retains activity against the Omicron variant.
About sotrovimab
Sotrovimab is an investigational SARS-CoV-2 neutralising monoclonal antibody. The antibody binds to an epitope on SARS-CoV-2 shared with SARS-CoV-1 (the virus that causes SARS), indicating that the epitope is highly conserved, which may make it more difficult for resistance to develop. Sotrovimab, which incorporates Xencor, Inc.’s Xtend™ technology, has also been designed to achieve high concentration in the lungs to ensure optimal penetration into airway tissues affected by SARS-CoV-2 and to have an extended half-life."""

contentText1= """ Abbott Labs Lifts FY24 Outlook After 2Q Sales Rise
Published: July 18, 2024 at 8:06 a.m. ET
By Dean Seal
Abbott Laboratories raised its full-year earnings guidance after reporting sales gains in the second quarter from its nutrition and medical devices segments.
The Abbott Park, Ill.-based healthcare products company said it now expects earnings of $3.30 to $3.40 a share, adding 5 cents to the lower end of its previous guidance.
When adjusted for one-time items, the company expects earnings of $4.61 to $4.71 a share, up from a prior range of $4.55 to $4.70 a share.
The company also increased the lower end of its outlook for organic sales growth, excluding Covid-19 testing, to 9.5% from 8.5%.

For the second quarter, the Pedialyte maker posted a profit of $1.3 billion, or 74 cents a share, compared with $1.38 billion, or 78 cents a share, in the same quarter a year ago.
Adjusted earnings were $1.14 a share, clearing analyst projections by 3 cents, according to FactSet.

Sales rose 4% to $10.38 billion, in line with analyst forecasts. The top line grew 7.4% on an organic basis, which excludes foreign currency translations, the discontinuing of its ZonePerfect product line and its acquisition of Cardiovascular Systems.
The company's adult nutrition segment performed well thanks to growth of its Ensure nutrition brand, while its diagnostics unit was dented by declines in Covid-19 testing-related sales.

Sales in its medical devices business were up more than 10%, led by its Diabetes Care, Electrophysiology, and Structural Heart products.
Write to Dean Seal at dean.seal@wsj.com """


contentText= """There are around 63 firm orders for the upcoming Airbus A350F based on the Airbus A350-900 passenger aircraft. The aircraft had been expected to enter service in 2026, but that has now been pushed back to 2027. Still, expectations are high for the Airbus A350F . Currently, the world is looking forward to the introduction of two new freighters, the Boeing 777X freighter and the Airbus A350F.
The A350 has proven a popular platform and one that is well adapted to being used as a freighter. This is in contrast with the Airbus A380, which is poorly designed to function as a freighter. Here is what to know about the orders for the Airbus A350F.

Airbus A350F orders
Ch-aviation lists that over nine customers have so far ordered 66 Airbus A350F cargo aircraft. Perhaps surprisingly, some of the big air freighter companies like DHL and FedEx do not appear to have placed firm orders for the aircraft."""

# %%
#Step 3 get intelligent tagging response from Hosted RIT

from dotenv import load_dotenv
import os

load_dotenv()
it_api_key = os.getenv('API_KEY9')

## Check if the API key is loaded correctly
## otherwise manually add

#print(it_api_key)

url= "https://api-eit.refinitiv.com/permid/calais" #endpoint
payload = contentText3.encode('utf8')
headers = {
    'Content-Type': "text/raw",
    'X-AG-Access-Token': it_api_key, # token called here
    'outputformat': "application/json",
    'x-calais-contentClass': "news",
    #'x-calais-selectiveTags': "topic-all, socialtags, industry, Organization, Person, Journalist, Company, Editor "
    }

TRITResponse = requests.post(url, data=payload, headers = headers)

# %%
print(TRITResponse.headers)
# Out:
# {'Date': 'Fri, 19 Sep 2025 00:15:24 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'RateLimit-Reset': '85482', 'RateLimit-Remaining': '4998', 'RateLimit-Limit': '5000', 'X-RateLimit-Limit-second': '2', 'X-RateLimit-Remaining-second': '1', 'X-RateLimit-Limit-day': '5000', 'X-RateLimit-Remaining-day': '4998', 'X-RateLimit-Remaining-RequestSize': '499998952', 'X-RateLimit-Limit-RequestSize': '500000000', 'Set-Cookie': 'TR-TMS-MDaaS-SESSIONID=AZlfU011JO7pptvM6eLS^3c5923f5;Path=/;HttpOnly', 'Expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'DurationMillis': '5881', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding, Origin', 'Access-Control-Allow-Credentials': 'true', 'Strict-Transport-Security': 'max-age=31536000'}

# %%
print(TRITResponse.text)
# Out:
# {"doc":{"info":{"id":"http:\/\/id.opencalais.com\/cVIvFpd5ZdK3L5C9H*ZvGw","ontology":"http:\/\/trit-us-east-1-sharedamd.int.refinitiv.com\/owlschema\/0.5.2\/onecalais.owl.allmetadata.xml","docId":"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc","document":"Thor Steel is introducing a new vibranium bread in the market. Thor Steel is new to the bread market. The bread launch will take place in stages, leading up to summer 2025. Thor Steel CEO, Bruce Banner, will be speaking more about the launch at Thor Steel shareholder lunch and launch. There are around 63 firm orders for the upcoming Airbus A350F based on the Airbus A350-900 passenger aircraft. The aircraft had been expected to enter service in 2026, but that has now been pushed back to 2027. Still, expectations are high for the Airbus A350F . Currently, the world is looking forward to the introduction of two new freighters, the Boeing 777X freighter and the Airbus A350F.\nThe A350 has proven a popular platform and one that is well adapted to being used as a freighter. This is in contrast with the Airbus A380, which is poorly designed to function as a freighter. Here is what to know about the orders for the Airbus A350F.\n\nAirbus A350F orders\nCh-aviation lists that over nine customers have so far ordered 66 Airbus A350F cargo aircraft.","docTitle":"","docDate":"2025-09-19 00:15:24.561"},"meta":{"contentClass":"news","contentType":"text\/raw","processingVer":"AllMetadata","serverVersion":"N\/A","stagsVer":"defaultVersion","submissionDate":"2025-09-19 00:15:24.269","submitterCode":"2362b867-7324-6cab-fb2e-2a48761bfb77","signature":"digestalg-1|QeHU6IL0gZGsctY8xP951gq19fg=|cBSwMP8xIB8m9Clv2txQ3pjtYZ0ge2HDjn0YxtAGehVij0wxnrS1MA==","language":"English"}},"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc\/cat\/1":{"_typeGroup":"topics","forenduserdisplay":"false","score":0.972,"name":"Business_Finance"},"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc\/cat\/2":{"_typeGroup":"topics","forenduserdisplay":"false","rcscode":"B:58","name":"Courier, Postal, Air Freight & Land-based Logistics","permid":"4294952943","score":0.5},"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc\/cat\/3":{"_typeGroup":"topics","forenduserdisplay":"false","rcscode":"B:37","name":"Aerospace & Defense (TRBC)","permid":"4294952964","score":0.647},"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc\/cat\/4":{"_typeGroup":"topics","forenduserdisplay":"false","rcscode":"B:22","name":"Iron & Steel","permid":"4294952979","score":0.627},"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc\/cat\/5":{"_typeGroup":"topics","forenduserdisplay":"true","rcscode":"E:6Q","name":"Product Launches","permid":"1000487254","score":0.454},"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc\/lid\/DefaultLangId":{"_typeGroup":"language","language":"http:\/\/d.opencalais.com\/lid\/DefaultLangId\/English","forenduserdisplay":"false","permid":"505062"},"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc\/SocialTag\/1":{"_typeGroup":"socialTag","id":"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc\/SocialTag\/1","socialTag":"http:\/\/d.opencalais.com\/genericHasher-1\/f0358f37-cd2d-3252-aa70-82e0de54e765","forenduserdisplay":"true","name":"Wide-body aircraft","importance":"1","originalValue":"Wide-body aircraft"},"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc\/SocialTag\/2":{"_typeGroup":"socialTag","id":"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc\/SocialTag\/2","socialTag":"http:\/\/d.opencalais.com\/genericHasher-1\/aeb75f0b-e92f-3021-a3ae-0db210309967","forenduserdisplay":"true","name":"Airbus A350","importance":"1","originalValue":"Airbus A350"},"http:\/\/d.opencalais.com\/dochash-1\/0dbdf9c3-c16e-3855-b376-ec0415801dbc\/SocialTag\/3":{"_typeGrou ...

# %%
JSONResponse = json.loads(TRITResponse.text)

# %%
print(json.dumps(JSONResponse, indent = 4))
# Out:
# {
#     "doc": {
#         "info": {
#             "id": "http://id.opencalais.com/cVIvFpd5ZdK3L5C9H*ZvGw",
#             "ontology": "http://trit-us-east-1-sharedamd.int.refinitiv.com/owlschema/0.5.2/onecalais.owl.allmetadata.xml",
#             "docId": "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc",
#             "document": "Thor Steel is introducing a new vibranium bread in the market. Thor Steel is new to the bread market. The bread launch will take place in stages, leading up to summer 2025. Thor Steel CEO, Bruce Banner, will be speaking more about the launch at Thor Steel shareholder lunch and launch. There are around 63 firm orders for the upcoming Airbus A350F based on the Airbus A350-900 passenger aircraft. The aircraft had been expected to enter service in 2026, but that has now been pushed back to 2027. Still, expectations are high for the Airbus A350F . Currently, the world is looking forward to the introduction of two new freighters, the Boeing 777X freighter and the Airbus A350F.\nThe A350 has proven a popular platform and one that is well adapted to being used as a freighter. This is in contrast with the Airbus A380, which is poorly designed to function as a freighter. Here is what to know about the orders for the Airbus A350F.\n\nAirbus A350F orders\nCh-aviation lists that over nine customers have so far ordered 66 Airbus A350F cargo aircraft.",
#             "docTitle": "",
#             "docDate": "2025-09-19 00:15:24.561"
#         },
#         "meta": {
#             "contentClass": "news",
#             "contentType": "text/raw",
#             "processingVer": "AllMetadata",
#             "serverVersion": "N/A",
#             "stagsVer": "defaultVersion",
#             "submissionDate": "2025-09-19 00:15:24.269",
#             "submitterCode": "2362b867-7324-6cab-fb2e-2a48761bfb77",
#             "signature": "digestalg-1|QeHU6IL0gZGsctY8xP951gq19fg=|cBSwMP8xIB8m9Clv2txQ3pjtYZ0ge2HDjn0YxtAGehVij0wxnrS1MA==",
#             "language": "English"
#         }
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/cat/1": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "false",
#         "score": 0.972,
#         "name": "Business_Finance"
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/cat/2": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "false",
#         "rcscode": "B:58",
#         "name": "Courier, Postal, Air Freight & Land-based Logistics",
#         "permid": "4294952943",
#         "score": 0.5
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/cat/3": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "false",
#         "rcscode": "B:37",
#         "name": "Aerospace & Defense (TRBC)",
#         "permid": "4294952964",
#         "score": 0.647
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/cat/4": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "false",
#         "rcscode": "B:22",
#         "name": "Iron & Steel",
#         "permid": "4294952979",
#         "score": 0.627
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/cat/5": {
#         "_typeGroup": "topics",
#         "forenduserdisplay": "true",
#         "rcscode": "E:6Q",
#         "name": "Product Launches",
#         "permid": "1000487254",
#         "score": 0.454
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/lid/DefaultLangId": {
#         "_typeGroup": "language",
#         "language": "http://d.opencalais.com/lid/DefaultLangId/English",
#         "forenduserdisplay": "false",
#         "permid": "505062"
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/1": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/1",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/f0358f37-cd2d-3252-aa70-82e0de54e765",
#         "forenduserdisplay": "true",
#         "name": "Wide-body aircraft",
#         "importance": "1",
#         "originalValue": "Wide-body aircraft"
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/2": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/2",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/aeb75f0b-e92f-3021-a3ae-0db210309967",
#         "forenduserdisplay": "true",
#         "name": "Airbus A350",
#         "importance": "1",
#         "originalValue": "Airbus A350"
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/3": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/3",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/39b76d6c-5c10-3b5d-9a42-15dff132408a",
#         "forenduserdisplay": "true",
#         "name": "Airbus",
#         "importance": "1",
#         "originalValue": "Airbus"
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/4": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/4",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/f60fb817-eb21-36d2-9bce-5f08441bfc12",
#         "forenduserdisplay": "true",
#         "name": "Airbus A380",
#         "importance": "2",
#         "originalValue": "Airbus A380"
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/5": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/5",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/f4d58f68-129c-3758-b5d1-bccd7c2986f1",
#         "forenduserdisplay": "true",
#         "name": "Cargo aircraft",
#         "importance": "2",
#         "originalValue": "Cargo aircraft"
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/6": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/6",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/a83a808d-1f60-39c3-87da-5ee6e95ccac1",
#         "forenduserdisplay": "true",
#         "name": "Boeing 777X",
#         "importance": "2",
#         "originalValue": "Boeing 777X"
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/7": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/7",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/90631996-12d0-36be-ae65-623df4db5efb",
#         "forenduserdisplay": "true",
#         "name": "Cathay Pacific fleet",
#         "importance": "2",
#         "originalValue": "Cathay Pacific fleet"
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/8": {
#         "_typeGroup": "socialTag",
#         "id": "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/SocialTag/8",
#         "socialTag": "http://d.opencalais.com/genericHasher-1/ffab923b-d33a-3c86-bfbf-3df11495a507",
#         "forenduserdisplay": "true",
#         "name": "Singapore Airlines fleet",
#         "importance": "2",
#         "originalValue": "Singapore Airlines fleet"
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/Industry/1": {
#         "_typeGroup": "industry",
#         "forenduserdisplay": "false",
#         "name": "Commercial Aircraft Manufacturing",
#         "rcscode": "B:1137",
#         "trbccode": "5210101012",
#         "permid": "4294951864",
#         "relevance": 0.5
#     },
#     "http://d.opencalais.com/dochash-1/0dbdf9c3-c16e-3855-b376-ec0415801dbc/ComponentVersions": {
#         "_typeGroup": "versions",
#         "version": [
#             "Deals Index:202508100812:202508100812",
#             "config-blackList-DIY:306617696:306617696",
#             "index-refineries:202403040723:202403040723",
#             "config-physicalAssets-powerStations:1227:1227",
#             "NextTags:2.5.193-legacy-trit-release-master:193",
#             "config-sca-DataPackage:50:50",
#             "config-companyNe:90617:90617",
#             "People Index:202509182307:202509182307",
#             "config-negativeSignature:994:994",
#             "Dial4J:2.0.17:17",
#             "OA Override:994:994",
#             "People Override:994:994",
#             "index-sluglines:202010230725:202010230725",
#             "index-vessels:202403050724:202403050724",
#             "config-forEndUserDisplay:4:4",
#             "config-refineries:994:994",
#             "config-cse-DIY:306606993:306606993",
#             "config-cse:994:994",
#             "config-vessels:994:994",
#             "override-company-DIY:306605404:306605404",
#             "config-physicalAssets-mines:1227:1227",
#             "BlackList:994:994",
#             "index-ports:202107101516:202107101516",
#             "config-physicalAssets-ports:994:994",
#             "config-drugs:994:994"
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/47d99e9b-a2c9-3bb3-8c37-93bd00c050a2": {
#         "_typeGroup": "entities",
#         "_type": "Product",
#         "forenduserdisplay": "false",
#         "name": "Airbus A350",
#         "producttype": "Aircraft",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Product",
#         "instances": [
#             {
#                 "detection": "[for the upcoming Airbus A350F based on the ]Airbus A350[-900 passenger aircraft. The aircraft had been]",
#                 "prefix": "for the upcoming Airbus A350F based on the ",
#                 "exact": "Airbus A350",
#                 "suffix": "-900 passenger aircraft. The aircraft had been",
#                 "offset": 361,
#                 "length": 11
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/e0501398-f81f-30ab-bd4b-c8554769e621": {
#         "_typeGroup": "entities",
#         "_type": "Product",
#         "forenduserdisplay": "false",
#         "name": "A350",
#         "producttype": "Aircraft",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Product",
#         "instances": [
#             {
#                 "detection": "[Boeing 777X freighter and the Airbus A350F.\nThe ]A350[ has proven a popular platform and one that is]",
#                 "prefix": "Boeing 777X freighter and the Airbus A350F.\nThe ",
#                 "exact": "A350",
#                 "suffix": " has proven a popular platform and one that is",
#                 "offset": 684,
#                 "length": 4
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/pershash-1/f62e72a3-2a3b-3bb5-a319-e0f5c784f31f": {
#         "_typeGroup": "entities",
#         "_type": "Person",
#         "forenduserdisplay": "true",
#         "confidencelevel": "0.95",
#         "name": "Bruce Banner",
#         "persontype": "N/A",
#         "firstname": "Bruce",
#         "lastname": "Banner",
#         "nationality": "N/A",
#         "commonname": "Bruce Banner",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Person",
#         "permid": "https://permid.org/1-404011",
#         "instances": [
#             {
#                 "detection": "[leading up to summer 2025. Thor Steel CEO, ]Bruce Banner[, will be speaking more about the launch at Thor]",
#                 "prefix": "leading up to summer 2025. Thor Steel CEO, ",
#                 "exact": "Bruce Banner",
#                 "suffix": ", will be speaking more about the launch at Thor",
#                 "offset": 189,
#                 "length": 12
#             }
#         ],
#         "relevance": 0.2,
#         "confidence": {
#             "statisticalfeature": "0.97",
#             "dblookup": "0.0",
#             "resolution": "0.0",
#             "aggregate": "0.95"
#         }
#     },
#     "http://d.opencalais.com/genericHasher-1/92d0fb98-6cb3-32f4-8d7d-560af8e94dfc": {
#         "_typeGroup": "entities",
#         "_type": "Product",
#         "forenduserdisplay": "false",
#         "name": "Airbus A380",
#         "producttype": "Aircraft",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Product",
#         "instances": [
#             {
#                 "detection": "[as a freighter. This is in contrast with the ]Airbus A380[, which is poorly designed to function as a]",
#                 "prefix": "as a freighter. This is in contrast with the ",
#                 "exact": "Airbus A380",
#                 "suffix": ", which is poorly designed to function as a",
#                 "offset": 807,
#                 "length": 11
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/comphash-1/1980a6bf-31a3-3844-a1a7-5af62a07c2f6": {
#         "_typeGroup": "entities",
#         "_type": "Company",
#         "forenduserdisplay": "false",
#         "name": "Thor Steel",
#         "nationality": "N/A",
#         "confidencelevel": "0.92",
#         "recognizedas": "name",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Company",
#         "instances": [
#             {
#                 "detection": "[]Thor Steel[ is introducing a new vibranium bread in the]",
#                 "exact": "Thor Steel",
#                 "suffix": " is introducing a new vibranium bread in the",
#                 "offset": 0,
#                 "length": 10
#             },
#             {
#                 "detection": "[ introducing a new vibranium bread in the market. ]Thor Steel[ is new to the bread market. The bread launch]",
#                 "prefix": " introducing a new vibranium bread in the market. ",
#                 "exact": "Thor Steel",
#                 "suffix": " is new to the bread market. The bread launch",
#                 "offset": 63,
#                 "length": 10
#             },
#             {
#                 "detection": "[ take place in stages, leading up to summer 2025. ]Thor Steel[ CEO, Bruce Banner, will be speaking more about]",
#                 "prefix": " take place in stages, leading up to summer 2025. ",
#                 "exact": "Thor Steel",
#                 "suffix": " CEO, Bruce Banner, will be speaking more about",
#                 "offset": 173,
#                 "length": 10
#             },
#             {
#                 "detection": "[will be speaking more about the launch at ]Thor Steel[ shareholder lunch and launch. There are around]",
#                 "prefix": "will be speaking more about the launch at ",
#                 "exact": "Thor Steel",
#                 "suffix": " shareholder lunch and launch. There are around",
#                 "offset": 245,
#                 "length": 10
#             }
#         ],
#         "relevance": 0.8,
#         "confidence": {
#             "statisticalfeature": "0.979",
#             "dblookup": "0.0",
#             "resolution": "0.0",
#             "aggregate": "0.92"
#         }
#     },
#     "http://d.opencalais.com/comphash-1/9c547cf2-af90-3766-b1c3-37bcdb79b593": {
#         "_typeGroup": "entities",
#         "_type": "Company",
#         "forenduserdisplay": "true",
#         "name": "the Boeing",
#         "nationality": "N/A",
#         "confidencelevel": "1.0",
#         "recognizedas": "name",
#         "confidence": {
#             "statisticalfeature": "0.857",
#             "dblookup": "0.0",
#             "resolution": "1.0",
#             "aggregate": "1.0"
#         },
#         "resolutions": [
#             {
#                 "name": "THE BOEING COMPANY",
#                 "permid": "4295903076",
#                 "primaryric": "BA.N",
#                 "ispublic": "true",
#                 "commonname": "Boeing",
#                 "score": 1,
#                 "id": "https://permid.org/1-4295903076",
#                 "ticker": "BA"
#             }
#         ],
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Company",
#         "instances": [
#             {
#                 "detection": "[to the introduction of two new freighters, ]the Boeing[ 777X freighter and the Airbus A350F.\nThe A350]",
#                 "prefix": "to the introduction of two new freighters, ",
#                 "exact": "the Boeing",
#                 "suffix": " 777X freighter and the Airbus A350F.\nThe A350",
#                 "offset": 632,
#                 "length": 10
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/comphash-1/78959001-0513-30c4-aca7-449de615b3c0": {
#         "_typeGroup": "entities",
#         "_type": "Company",
#         "forenduserdisplay": "true",
#         "name": "The Airbus",
#         "confidencelevel": "1.0",
#         "recognizedas": "name",
#         "confidence": {
#             "statisticalfeature": "0.862",
#             "dblookup": "0.0",
#             "resolution": "1.0",
#             "aggregate": "1.0"
#         },
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Company",
#         "instances": [
#             {
#                 "detection": "[orders for the upcoming Airbus A350F based on ]the Airbus[ A350-900 passenger aircraft. The aircraft had]",
#                 "prefix": "orders for the upcoming Airbus A350F based on ",
#                 "exact": "the Airbus",
#                 "suffix": " A350-900 passenger aircraft. The aircraft had",
#                 "offset": 357,
#                 "length": 10
#             },
#             {
#                 "detection": "[back to 2027. Still, expectations are high for ]the Airbus[ A350F . Currently, the world is looking forward]",
#                 "prefix": "back to 2027. Still, expectations are high for ",
#                 "exact": "the Airbus",
#                 "suffix": " A350F . Currently, the world is looking forward",
#                 "offset": 530,
#                 "length": 10
#             },
#             {
#                 "detection": "[new freighters, the Boeing 777X freighter and ]the Airbus[ A350F.\nThe A350 has proven a popular platform]",
#                 "prefix": "new freighters, the Boeing 777X freighter and ",
#                 "exact": "the Airbus",
#                 "suffix": " A350F.\nThe A350 has proven a popular platform",
#                 "offset": 662,
#                 "length": 10
#             },
#             {
#                 "detection": "[used as a freighter. This is in contrast with ]the Airbus[ A380, which is poorly designed to function as a]",
#                 "prefix": "used as a freighter. This is in contrast with ",
#                 "exact": "the Airbus",
#                 "suffix": " A380, which is poorly designed to function as a",
#                 "offset": 803,
#                 "length": 10
#             },
#             {
#                 "detection": "[Here is what to know about the orders for ]the Airbus[ A350F.\n\nAirbus A350F orders\nCh-aviation lists]",
#                 "prefix": "Here is what to know about the orders for ",
#                 "exact": "the Airbus",
#                 "suffix": " A350F.\n\nAirbus A350F orders\nCh-aviation lists",
#                 "offset": 915,
#                 "length": 10
#             },
#             {
#                 "detection": "[ There are around 63 firm orders for the upcoming ]Airbus[ A350F based on the Airbus A350-900 passenger]",
#                 "prefix": " There are around 63 firm orders for the upcoming ",
#                 "exact": "Airbus",
#                 "suffix": " A350F based on the Airbus A350-900 passenger",
#                 "offset": 335,
#                 "length": 6
#             },
#             {
#                 "detection": "[to know about the orders for the Airbus A350F.\n\n]Airbus[ A350F orders\nCh-aviation lists that over nine]",
#                 "prefix": "to know about the orders for the Airbus A350F.\n\n",
#                 "exact": "Airbus",
#                 "suffix": " A350F orders\nCh-aviation lists that over nine",
#                 "offset": 934,
#                 "length": 6
#             },
#             {
#                 "detection": "[that over nine customers have so far ordered 66 ]Airbus[ A350F cargo aircraft.]",
#                 "prefix": "that over nine customers have so far ordered 66 ",
#                 "exact": "Airbus",
#                 "suffix": " A350F cargo aircraft.",
#                 "offset": 1020,
#                 "length": 6
#             }
#         ],
#         "relevance": 0.5,
#         "resolutions": [
#             {
#                 "name": "Airbus SE",
#                 "permid": "4295884955",
#                 "primaryric": "AIR.PA",
#                 "ispublic": "true",
#                 "commonname": "Airbus NL",
#                 "score": 1,
#                 "id": "https://permid.org/1-4295884955",
#                 "ticker": "AIR"
#             }
#         ]
#     },
#     "http://d.opencalais.com/genericHasher-1/7179d419-6f3e-3ac4-a756-2b52b36c7fea": {
#         "_typeGroup": "entities",
#         "_type": "Position",
#         "forenduserdisplay": "false",
#         "name": "CEO",
#         "_typeReference": "http://s.opencalais.com/1/type/em/e/Position",
#         "instances": [
#             {
#                 "detection": "[ in stages, leading up to summer 2025. Thor Steel ]CEO[, Bruce Banner, will be speaking more about the]",
#                 "prefix": " in stages, leading up to summer 2025. Thor Steel ",
#                 "exact": "CEO",
#                 "suffix": ", Bruce Banner, will be speaking more about the",
#                 "offset": 184,
#                 "length": 3
#             }
#         ],
#         "relevance": 0.2
#     },
#     "http://d.opencalais.com/genericHasher-1/a3294fd2-3373-3ce7-919a-d1f47e198069": {
#         "_typeGroup": "relations",
#         "_type": "PersonCareer",
#         "forenduserdisplay": "true",
#         "position": "CEO",
#         "careertype": "professional",
#         "status": "current",
#         "_typeReference": "http://s.opencalais.com/1/type/em/r/PersonCareer",
#         "person": "http://d.opencalais.com/pershash-1/f62e72a3-2a3b-3bb5-a319-e0f5c784f31f",
#         "company": "http://d.opencalais.com/comphash-1/1980a6bf-31a3-3844-a1a7-5af62a07c2f6",
#         "instances": [
#             {
#                 "detection": "[ take place in stages, leading up to summer 2025. ]Thor Steel CEO, Bruce Banner[, will be speaking more about the launch at Thor]",
#                 "prefix": " take place in stages, leading up to summer 2025. ",
#                 "exact": "Thor Steel CEO, Bruce Banner",
#                 "suffix": ", will be speaking more about the launch at Thor",
#                 "offset": 173,
#                 "length": 28
#             }
#         ]
#     }
# }

# %%
res = TRITResponse.json()

# %%
#import json
#import pandas as pd

# Load the JSON data 
#file_path = "/mnt/data/updatedtest.json"
#with open(file_path, "r", encoding="utf-8") as file:
#    data = json.load(file)

# Prepare lists to collect categorized entries
socialtags = []
industries = []
companies = []
persons = []
topics =[]

# Categorize based on _typeGroup and _type
for key, value in res.items():
    if value.get("_typeGroup") == "socialTag":
        socialtags.append(value)
    elif value.get("_typeGroup") == "industry":
        industries.append(value)
    elif value.get("_typeGroup") == "topics":
        topics.append(value)
    elif value.get("_typeGroup") == "entities":
        if value.get("_type") == "Company":
            companies.append(value)
        elif value.get("_type") == "Person":
            persons.append(value)

# Convert each list into a DataFrame
df_socialtags = pd.DataFrame(socialtags)
df_industries = pd.DataFrame(industries)
df_companies = pd.DataFrame(companies)
df_persons = pd.DataFrame(persons)
df_topics = pd.DataFrame(topics)

# %%
def pretty_print(df, col_widths=None, headers=True):
    """
    Pretty-print a pandas DataFrame with left-aligned columns in the console.

    Args:
        df (pd.DataFrame): The DataFrame to print.
        col_widths (dict): Optional dict to set column widths. Example: {'name': 30, 'importance': 10}
        headers (bool): Whether to print headers or not.
    """
    if col_widths is None:
        # Default widths: auto-set based on longest entry in each column or 15
        col_widths = {
            col: max(df[col].astype(str).map(len).max(), len(str(col)), 15)
            for col in df.columns
        }

    # Format string builder
    fmt = "  ".join([f"{{:<{col_widths[col]}}}" for col in df.columns])

    # Print headers
    if headers:
        print(fmt.format(*df.columns))
        print("-" * (sum(col_widths.values()) + 2 * (len(col_widths) - 1)))

    # Print rows
    for _, row in df.iterrows():
        print(fmt.format(*[str(row[col]) for col in df.columns]))

# %%
#print(df_socialtags)

# Extract only the 'name','importance' field from social tags
df_socialtags_filtered = df_socialtags[['name', 'importance']].sort_values(by=['importance'],ascending=True)


#df_socialtagssorted = df_socialtags_filtered.sort_values(by=['importance'], ascending=False)
#tools.display_dataframe_to_user(name="Filtered SocialTags", dataframe=df_socialtags_filtered)
#print(df_socialtags_filtered.to_string(index=False,justify='left'))

pretty_print(df_socialtags_filtered)
# Out:
# name                      importance
# -----------------------------------------
# Wide-body aircraft        1
# Airbus A350               1
# Airbus                    1
# Airbus A380               2
# Cargo aircraft            2
# Boeing 777X               2
# Cathay Pacific fleet      2
# Singapore Airlines fleet  2

# %%
# Extract 'name', 'permid', 'relevance' fields from industries
df_industries_filtered = df_industries[['name', 'permid', 'relevance']].sort_values(by=['relevance'],ascending=False)

#tools.display_dataframe_to_user(name="Filtered Industries", dataframe=df_industries_filtered)
#print(df_industries_filtered.to_string(index=False,justify='left'))

pretty_print(df_industries_filtered)
# Out:
# name                               permid           relevance
# -------------------------------------------------------------------
# Commercial Aircraft Manufacturing  4294951864       0.5

# %%
company_data = []

for company in companies:
    name = company.get("name")
    relevance = company.get("relevance")
    resolutions = company.get("resolutions", [])

    # Default permid is None unless we find one
    permid = None
    if isinstance(resolutions, list) and len(resolutions) > 0:
        permid = resolutions[0].get("permid")

    company_data.append({
        "name": name,
        "permid": permid,
        "relevance": relevance
    })

# Create a DataFrame from the cleaned-up list
df_company_resolved = pd.DataFrame(company_data).sort_values(by=['relevance'],ascending=False)

#print(df_company_resolved)
pretty_print(df_company_resolved)
# Out:
# name             permid           relevance
# -------------------------------------------------
# Thor Steel       None             0.8
# The Airbus       4295884955       0.5
# the Boeing       4295903076       0.2

# %%
company_resolutions = []

for company in companies:
    name = company.get("name")
    relevance = company.get("relevance")
    confidence_level = company.get("confidencelevel")
    confidence_agg = company.get("confidence", {}).get("aggregate")

    resolutions = company.get("resolutions")

    if resolutions and isinstance(resolutions, list):
        # One row per resolution
        for res in resolutions:
            company_resolutions.append({
                "name": name,
                "relevance": relevance,
                "confidence_level": confidence_level,
                #"confidence_aggregate": confidence_agg,
                "permid": res.get("permid"),
                "RIC": res.get("primaryric"),
                "resolution_score": res.get("score")
            })
    else:  #This part is to handle if no resolutions present. Remove if necessary/still add the company info, with null resolution fields
        company_resolutions.append({
            "name": name,
            "relevance": relevance,
            "confidence_level": confidence_level,
            #"confidence_aggregate": confidence_agg,
            "permid": None,
            "RIC": None,
            "resolution_score": None
        })

df_company_resolutions = pd.DataFrame(company_resolutions).sort_values(by=['relevance'],ascending=False)
pretty_print(df_company_resolutions)
# Out:
# name             relevance        confidence_level  permid           RIC              resolution_score
# ------------------------------------------------------------------------------------------------------
# Thor Steel       0.8              0.92              None             None             nan
# The Airbus       0.5              1.0               4295884955       AIR.PA           1.0
# the Boeing       0.2              1.0               4295903076       BA.N             1.0

# %%
# Extract only the 'name' field from person tags

person_resolutions = []

for person in persons:
    name = person.get("name")
    relevance = person.get("relevance")
    confidence_level = person.get("confidencelevel")
    confidence_agg = person.get("confidence", {}).get("aggregate")

    resolutions = person.get("resolutions")

    if resolutions and isinstance(resolutions, list):
        # One row per resolution
        for res in resolutions:
            person_resolutions.append({
                "name": name,
                "relevance": relevance,
                "confidence_level": confidence_level,
                #"confidence_aggregate": confidence_agg,
                "permid": res.get("paid"),
                "resolution_score": res.get("score")
            })
    else:
        # No resolutions — still add the person info, with null resolution fields
        person_resolutions.append({
            "name": name,
            "relevance": relevance,
            "confidence_level": confidence_level,
            #"confidence_aggregate": confidence_agg,
            "permid": None,
            "resolution_score": None
        })

df_person_resolutions = pd.DataFrame(person_resolutions).sort_values(by=['relevance'],ascending=False)
pretty_print(df_person_resolutions)
# Out:
# name             relevance        confidence_level  permid           resolution_score
# -------------------------------------------------------------------------------------
# Bruce Banner     0.2              0.95              None             None

# %%
# Extract only the 'name' field from topic tags
df_topics_filtered = df_topics[['name','permid', 'score']].sort_values(by=['score'],ascending=False)

#tools.display_dataframe_to_user(name="Filtered SocialTags", dataframe=df_topic_filtered)
#print(df_topics_filtered)
pretty_print(df_topics_filtered)
# Out:
# name                                                 permid           score
# -------------------------------------------------------------------------------------
# Business_Finance                                     nan              0.972
# Aerospace & Defense (TRBC)                           4294952964       0.647
# Iron & Steel                                         4294952979       0.627
# Courier, Postal, Air Freight & Land-based Logistics  4294952943       0.5
# Product Launches                                     1000487254       0.454
